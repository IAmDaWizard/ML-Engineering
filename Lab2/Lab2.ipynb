# %% [markdown]
# # 2 ЛАБОРАТОРНАЯ РАБОТА ПО ФРЕЙМВОРКАМ ДЛЯ ML
# ### Выполнена студентом 102 группы, Дубчаком Александром.

# %% [markdown]
# ```
# Отдельные слова благодарности преподавателю Амелии Вадимовне за такую крутую задумку в стиле Cicada 3301 ;)))
# ```

# %% [markdown]
# ### С помощью библиотек pandas, openpyxl получим доступ ко всем excel-листам датафрейма.
#
# Сперва, на первом листе выделим все ячейки и поставим черный шрифт для того чтобы данные ячеек стали видны. Теперь все колонки приняли человеческий вид, кроме колонок "City", "Unnamed: 20", "Unnamed: 24". Дело в том, по всему листу разбросаны куски датасета, которые впоследствии придется собрать в единый датасет, но для начала решим проблему с колонками. Очевидно, сбита кодировка, для восстановления кодировки текста в ячейках этих колонках с помощью библиотек pandas и openpyxl сделаем следующее:

# %%
import pandas as pd

df = pd.read_excel("have_fun.xlsx", sheet_name=None)

def fix_text(s):
    if not isinstance(s, str):
        return s
    try:
        return s.encode("latin1").decode("cp1251")
    except:
        return s

for name, sheet in df.items():
    print("Лист:", name)
    print("Колонки:", list(sheet.columns))
    for col in sheet.columns:
        if str(col).strip().lower() == "city" or str(col).strip() == "Unnamed: 20" or str(col).strip() == "Unnamed: 24":
            sheet[col] = sheet[col].apply(fix_text)

with pd.ExcelWriter("fixed_2_have_fun.xlsx") as writer:
    for name, sheet in df.items():
        sheet.to_excel(writer, sheet_name=name, index=False)
# Out:
# Лист: Ëèñò1
# Колонки: ['temperature_2m', 'relative_humidity_2m', 'precipitation', 'rain', 'snowfall', 'weathercode', 'wind_speed_10m', 'surface_pressure', 'ds', 'city']
# Лист: Лист1
# Колонки: []
# Лист: ÌÀÈ
# Колонки: []
# Лист: ýòî
# Колонки: []
# Лист: ÿ
# Колонки: []
# Лист: !
# Колонки: []
# Лист: Ëèñò2_ñòðîêîâûå_NaN_âûáðîñû
# Колонки: ['temperature_2m', 'relative_humidity_2m', 'precipitation', 'rain', 'snowfall', 'weathercode', 'wind_speed_10m', 'surface_pressure', 'ds', 'city', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24']
# Лист: Ëèñò3_ñìåøàííûå_òèïû
# Колонки: ['temperature_2m', 'relative_humidity_2m', 'precipitation', 'rain', 'snowfall', 'weathercode', 'wind_speed_10m', 'surface_pressure', 'ds', 'city']

# %% [markdown]
# После того как мы получили исправленный Excel-файл "fixed_2_have_fun.xlsx", отсортируем листы в порядке значимости: пустые листы убираем в конец, после чего остается 3 листа, с которыми предстоит продолжить работу.
#
# Далее, перекодируем названия этих трех листов:

# %%
name1 = "Ëèñò1"
print(name1.encode("latin1").decode("cp1251"))
name2 = "Ëèñò2_ñòðîêîâûå_NaN_âûáðîñû"
print(name2.encode("latin1").decode("cp1251"))
name3 = "Ëèñò3_ñìåøàííûå_òèïû"
print(name3.encode("latin1").decode("cp1251"))
# Out:
# Лист1
# Лист2_строковые_NaN_выбросы
# Лист3_смешанные_типы

# %% [markdown]
# Далее, некая часть кусочного датасета вставляется вместо картинки с котиком, другая часть является дубликатом уже имещихся данных на своем месте. Часть куска датасета, где в колонке city значатся Благовещенск и Геленджик, отправляется в первый лист, так как на втором листе присутствуют данные, значения которых в колонке city - Москва, Находка, в отличие от листа 1.
#
# Для полного восстановления датасета лишь осталось удалить пустые строки между строками данных.

# %% [markdown]
# Удаление пустых строк:

# %%
import pandas as pd

df = pd.read_excel("fixed_2_have_fun.xlsx", sheet_name=None)

# удаляем полностью пустые строки
for name, sheet in df.items():
    sheet = sheet.replace(r'^\s*$', pd.NA, regex=True)
    df[name] = sheet.dropna(how='all')

# сохраняем НОВЫЙ файл
with pd.ExcelWriter("clean_have_fun.xlsx", engine="openpyxl") as writer:
    for name, sheet in df.items():
        sheet.to_excel(writer, sheet_name=name, index=False)

# %% [markdown]
# На данном этапе был успешно восстановлен доступ ко всем данным Excel-файла, включая скрытые листы. Были исправлены проблемы кодировки, проверена корректность временных меток и уникальность наблюдений по комбинации город–время. После восстановления датасет стал пригоден для дальнейшей предобработки и анализа временных рядов.

# %% [markdown]
# # Предобработка данных

# %% [markdown]
# Проверим, есть ли дубликаты на наших 3 листах с данными. Проверим это в Excel с помощью формулы:

# %% [markdown]
# ```=IF(AND(J4=J5, I4=I5), 1, K3)```

# %% [markdown]
# ![alt text](<Screenshot 2026-05-09 at 1.38.45 PM.png>)
# ![alt text](<Screenshot 2026-05-09 at 1.39.03 PM.png>)
# ![alt text](<Screenshot 2026-05-09 at 1.39.16 PM.png>)

# %% [markdown]
# Как видно по результату, дубликаты есть только на первом листе. Удалим их:

# %%
for name, sheet in df.items():
    if 'city' in sheet.columns and 'ds' in sheet.columns:
        df[name] = sheet.drop_duplicates(subset=['city', 'ds'])

# %% [markdown]
# Исправим ошибки в названиях городов на каждом листе:

# %%
for name, sheet in df.items():
    if "city" in sheet.columns:
        sheet["city"] = sheet["city"].replace(["nan", "NaN", "None", ""], pd.NA)
        sheet["city"] = sheet["city"].str.strip().str.title()
        sheet["city"] = sheet["city"].replace({
            "Благовещенс": "Благовещенск",
            "Благовещенскк": "Благовещенск",
            "Геленджи": "Геленджик",
            "Геленджикк": "Геленджик",
            "Мосва": "Москва",
            "Соч": "Сочи",
            "Счи": "Сочи",
            "Сычи": "Сочи"
        })
        sheet = sheet.dropna(subset=["city"])
        df[name] = sheet

with pd.ExcelWriter("cleaned_2_have_fun.xlsx", engine="openpyxl") as writer:
    for name, sheet in df.items():
        if sheet.index.name == "ds":
            sheet.reset_index().to_excel(writer, sheet_name=name, index=False)
        else:
            sheet.to_excel(writer, sheet_name=name, index=False)

for name, sheet in df.items():
    if "city" in sheet.columns:
        print(name)
        print(sheet["city"].unique())
        print("=" * 40)
# Out:
# Лист1
# <ArrowStringArray>
# ['Геленджик', 'Благовещенск']
# Length: 2, dtype: str
# ========================================
# Лист2_строковые_NaN_выбросы
# <ArrowStringArray>
# ['Москва', 'Находка']
# Length: 2, dtype: str
# ========================================
# Лист3_смешанные_типы
# <ArrowStringArray>
# ['Санкт-Петербург', 'Сочи']
# Length: 2, dtype: str
# ========================================

# %% [markdown]
# Проверяем пропуски в колонках city:

# %%
import pandas as pd
df = pd.read_excel("cleaned_2_have_fun.xlsx", sheet_name=None)
for name, sheet in df.items():
    if "city" in sheet.columns:
        print(name, sheet["city"].isna().sum())
# Out:
# Лист1 0
# Лист2_строковые_NaN_выбросы 0
# Лист3_смешанные_типы 0

# %% [markdown]
# Как и ожидалось, пропусков в колонках city нет, поэтому приведем данные к единому временному индексу, отсортируем их по времени, поставим в качестве индекса датафрейма время и приведем данные к ежедневной частоте:

# %%
for name, sheet in df.items():
    if "ds" in sheet.columns and "city" in sheet.columns:
        sheet["ds"] = pd.to_datetime(sheet["ds"])
        sheet = sheet.sort_values(["city", "ds"])

        parts = []

        for city, city_df in sheet.groupby("city"):
            city_df = city_df.sort_values("ds")
            city_df = city_df.set_index("ds")
            city_df = city_df.asfreq("h")
            city_df["city"] = city 

            parts.append(city_df)           
                                
        df[name] = pd.concat(parts)

# %% [markdown]
# Займемся обработкой пропусков числовых признаков. Для начала оценим число строк с пропущенными числовыми признаками:

# %%
numeric_cols = ["temperature_2m", "relative_humidity_2m", "precipitation", "rain", "snowfall", "weathercode", "wind_speed_10m", "surface_pressure", "ds"]

for name, sheet in df.items():
    print(f"\nЛист: {name}")

    for col in numeric_cols:
        if col in sheet.columns: # числовые признаки
            missing = sheet[col].isna().sum()
            print(f"{col}: {missing}")
# Out:
# Лист: Лист1
# temperature_2m: 1841
# relative_humidity_2m: 0
# precipitation: 1227
# rain: 0
# snowfall: 0
# weathercode: 0
# wind_speed_10m: 1227
# surface_pressure: 0
#
# Лист: Лист2_строковые_NaN_выбросы
# temperature_2m: 683
# relative_humidity_2m: 4
# precipitation: 690
# rain: 4
# snowfall: 4
# weathercode: 4
# wind_speed_10m: 354
# surface_pressure: 4
#
# Лист: Лист3_смешанные_типы
# temperature_2m: 5
# relative_humidity_2m: 5
# precipitation: 249
# rain: 0
# snowfall: 0
# weathercode: 0
# wind_speed_10m: 0
# surface_pressure: 0
#
# Лист: нафек
#
# Лист: МАИ
#
# Лист: это
#
# Лист: я
#
# Лист: !

# %% [markdown]
# После приведения временных рядов к единой почасовой частоте в данных появились пропуски, соответствующие отсутствующим временным наблюдениям. Наибольшее количество пропусков наблюдается в признаках temperature_2m, precipitation и wind_speed_10m, что связано с наличием пропущенных часов в исходных временных рядах. Кроме того, после преобразования признаков к числовому типу с помощью pd.to_numeric(errors="coerce") были обнаружены единичные некорректные строковые значения, автоматически преобразованные в NaN.
# Поскольку погодные параметры изменяются относительно плавно во времени, для восстановления пропущенных значений было принято решение использовать временную интерполяцию. В отличие от удаления строк, интерполяция позволяет сохранить непрерывность временного ряда и не нарушать временную структуру данных, что особенно важно для последующего прогнозирования.

# %%
numeric_cols = ["temperature_2m", "relative_humidity_2m", "precipitation", "rain", "snowfall", "weathercode", "wind_speed_10m", "surface_pressure"]

for name, sheet in df.items():
    if sheet.index.name == "ds":
        existing_num = [col for col in numeric_cols if col in sheet.columns]
        for col in existing_num:
            sheet[col] = pd.to_numeric(sheet[col], errors="coerce")
        sheet[existing_num] = sheet[existing_num].interpolate(method="time", limit_direction="both")
        df[name] = sheet

# %%
# удаляем лишние колонки
for name, sheet in df.items():
    sheet = sheet.loc[:, ~sheet.columns.astype(str).str.startswith("Unnamed")]
    if "duplicates" in sheet.columns:
        sheet = sheet.drop(columns=["duplicates"])
    df[name] = sheet

# %% [markdown]
# Проверяем пропуски:

# %%
for name, sheet in df.items():
    print(f"\nЛист: {name}")
    print(sheet.isna().sum())
# Out:
# Лист: Лист1
# temperature_2m          0
# relative_humidity_2m    0
# precipitation           0
# rain                    0
# snowfall                0
# weathercode             0
# wind_speed_10m          0
# surface_pressure        0
# city                    0
# dtype: int64
#
# Лист: Лист2_строковые_NaN_выбросы
# temperature_2m          0
# relative_humidity_2m    0
# precipitation           0
# rain                    0
# snowfall                0
# weathercode             0
# wind_speed_10m          0
# surface_pressure        0
# city                    0
# dtype: int64
#
# Лист: Лист3_смешанные_типы
# temperature_2m          0
# relative_humidity_2m    0
# precipitation           0
# rain                    0
# snowfall                0
# weathercode             0
# wind_speed_10m          0
# surface_pressure        0
# city                    0
# dtype: int64
#
# Лист: нафек
# Series([], dtype: float64)
#
# Лист: МАИ
# Series([], dtype: float64)
#
# Лист: это
# Series([], dtype: float64)
#
# Лист: я
# Series([], dtype: float64)
#
# Лист: !
# Series([], dtype: float64)

# %% [markdown]
# В результате обработки пропусков удалось восстановить непрерывные временные ряды для всех городов. Категориальные признаки были предварительно очищены от пропусков, после чего данные были приведены к единой почасовой временной сетке. Возникшие после этого пропуски в числовых признаках были восстановлены с помощью временной интерполяции (method="time"), учитывающей реальное расстояние между временными наблюдениями.
# Дополнительно числовые признаки были приведены к корректному числовому типу данных с использованием pd.to_numeric(errors="coerce"), что позволило обнаружить и обработать некорректные строковые значения. После завершения интерполяции в рабочих листах не осталось пропущенных значений, что позволяет переходить к анализу выбросов и исследованию временных рядов.

# %% [markdown]
# Переходим к обработке выбросов, посмотрим статистику по числовым признакам для каждого города:

# %%
numeric_cols = ["temperature_2m", "relative_humidity_2m", "precipitation", "rain", "snowfall", "wind_speed_10m", "surface_pressure"]

for name, sheet in df.items():
    if sheet.index.name == "ds":

        for city, city_df in sheet.groupby("city"):

            print(f"\n{name} — {city}")

            display(city_df[numeric_cols].describe())
# Out:
# Лист1 — Благовещенск
#        temperature_2m  relative_humidity_2m  ...  wind_speed_10m  surface_pressure
# count    61368.000000          61368.000000  ...    61368.000000      61368.000000
# mean         2.390208             66.511749  ...       10.223120        996.415541
# std         15.962655             19.189955  ...        5.257160          9.108933
# min        -41.900002             11.000000  ...        0.000000        969.700012
# 25%        -11.400000             53.000000  ...        6.600000        989.500000
# 50%          3.800000             69.000000  ...        9.400000        995.900024
# 75%         16.400000             81.000000  ...       13.000000       1003.099976
# max         36.500000            100.000000  ...       41.599998       1029.400024
#
# [8 rows x 7 columns]
# Лист1 — Геленджик
#        temperature_2m  relative_humidity_2m  ...  wind_speed_10m  surface_pressure
# count    61368.000000          61368.000000  ...    61368.000000      61368.000000
# mean        14.170815             74.439252  ...       13.986702       1015.330335
# std          8.835669             17.136832  ...        8.324531          6.401923
# min        -33.599998             16.000000  ...        0.000000        987.000000
# 25%          7.900000             64.000000  ...        7.400000       1010.700012
# 50%         13.800000             78.000000  ...       12.400000       1014.799988
# 75%         21.200001             88.000000  ...       19.000000       1019.599976
# max         37.799999            100.000000  ...       56.099998       1034.699951
#
# [8 rows x 7 columns]
# Лист2_строковые_NaN_выбросы — Москва
#        temperature_2m  relative_humidity_2m  ...  wind_speed_10m  surface_pressure
# count    61368.000000          61368.000000  ...    61368.000000      61368.000000
# mean         6.910889             75.754595  ...       15.074853        991.689805
# std         11.857382             16.976641  ...       15.149487         12.739121
# min        -49.983136             16.000000  ...        0.000000        801.983606
# 25%         -1.000000             65.000000  ...        8.900000        985.599976
# 50%          6.500000             80.000000  ...       13.200000        991.799988
# 75%         15.400000             89.000000  ...       18.400000        998.000000
# max         79.974214            100.000000  ...      249.928074       1198.366026
#
# [8 rows x 7 columns]
# Лист2_строковые_NaN_выбросы — Находка
#        temperature_2m  relative_humidity_2m  ...  wind_speed_10m  surface_pressure
# count    61347.000000          61347.000000  ...    61347.000000      61347.000000
# mean         7.065817             70.580305  ...        9.888583       1010.304331
# std         12.713433             21.807973  ...       14.103111         11.561182
# min        -49.990098              9.000000  ...        0.000000        800.185777
# 25%         -2.300000             53.000000  ...        5.300000       1004.500000
# 50%          7.800000             74.000000  ...        8.200000       1010.400024
# 75%         17.000000             90.000000  ...       11.900000       1016.299988
# max         79.967297            100.000000  ...      249.822572       1199.037397
#
# [8 rows x 7 columns]
# Лист3_смешанные_типы — Санкт-Петербург
#        temperature_2m  relative_humidity_2m  ...  wind_speed_10m  surface_pressure
# count    61368.000000          61368.000000  ...    61368.000000      61368.000000
# mean         6.873017             79.039206  ...       14.535967       1012.383721
# std          9.634376             15.123788  ...        6.836831         11.253417
# min        -28.799999             15.000000  ...        0.000000        964.099976
# 25%          0.200000             71.000000  ...        9.400000       1005.700012
# 50%          6.000000             83.000000  ...       13.800000       1013.099976
# 75%         14.700000             90.000000  ...       18.900000       1019.799988
# max         35.700001            100.000000  ...       53.700001       1054.800049
#
# [8 rows x 7 columns]
# Лист3_смешанные_типы — Сочи
#        temperature_2m  relative_humidity_2m  ...  wind_speed_10m  surface_pressure
# count    61368.000000          61368.000000  ...    61368.000000      61368.000000
# mean        14.956657             77.851486  ...        8.898747       1015.125663
# std          7.539398             13.932590  ...        5.618099          6.236295
# min        -21.900000             24.000000  ...        0.000000        989.200012
# 25%          9.100000             69.000000  ...        4.900000       1010.599976
# 50%         14.700000             80.000000  ...        7.600000       1014.799988
# 75%         21.299999             89.000000  ...       11.500000       1019.400024
# max         35.299999            100.000000  ...       50.900002       1035.400024
#
# [8 rows x 7 columns]

# %% [markdown]
# Посторим boxplot для каждого города:

# %%
import matplotlib.pyplot as plt

numeric_cols = ["temperature_2m", "relative_humidity_2m", "precipitation", "rain", "snowfall", "wind_speed_10m", "surface_pressure"]

for name, sheet in df.items():
    if sheet.index.name == "ds":

        for city, city_df in sheet.groupby("city"):

            for col in numeric_cols:

                plt.figure(figsize=(6, 3))
                plt.boxplot(city_df[col].dropna(), vert=False)
                plt.title(f"{name} | {city} | {col}")
                plt.show()

# %% [markdown]
# После анализа графиков было установлено, что выбросы присутствуют в следующих данных:
#
# - temperature_2m, Москва (меньше -42,2, больше +40)
# - precipitation, Москва (больше +200)
# - wind_speed_10m, Москва (больше +100)
# - surface_pressure, Москва (меньше +900, больше +1100)
#
# - temperature_2m, Находка (меньше -30, больше +40)
# - precipitation, Находка (больше +400)
# - wind_speed_10m, Находка (больше +100)
# - surface_pressure, Находка (меньше +900, больше +1100)
#
# - temperature_2m, Сочи (меньше -13,4)

# %% [markdown]
# Обработаем все выбросы в данных с помощью замены на pd.NA и последующей интерполяции.

# %%
for name, sheet in df.items():
    if "city" in sheet.columns:
        for city, city_df in sheet.groupby("city"):
            if city == "Москва":
                sheet.loc[(sheet["city"] == city) & ((sheet["temperature_2m"] < -42.2) | (sheet["temperature_2m"] > 40)), "temperature_2m"] = pd.NA
                sheet.loc[(sheet["city"] == city) & (sheet["precipitation"] > 200), "precipitation"] = pd.NA
                sheet.loc[(sheet["city"] == city) & (sheet["wind_speed_10m"] > 100), "wind_speed_10m"] = pd.NA
                sheet.loc[(sheet["city"] == city) & ((sheet["surface_pressure"] < 900) | (sheet["surface_pressure"] > 1100)), "surface_pressure"] = pd.NA
            if city == "Находка":
                sheet.loc[(sheet["city"] == city) & ((sheet["temperature_2m"] < -30) | (sheet["temperature_2m"] > 40)), "temperature_2m"] = pd.NA
                sheet.loc[(sheet["city"] == city) & (sheet["precipitation"] > 400), "precipitation"] = pd.NA
                sheet.loc[(sheet["city"] == city) & (sheet["wind_speed_10m"] > 100), "wind_speed_10m"] = pd.NA
                sheet.loc[(sheet["city"] == city) & ((sheet["surface_pressure"] < 900) | (sheet["surface_pressure"] > 1100)), "surface_pressure"] = pd.NA
            if city == "Сочи":
                sheet.loc[(sheet["city"] == city) & (sheet["temperature_2m"] < -13.4), "temperature_2m"] = pd.NA

        df[name] = sheet

numeric_cols = ["temperature_2m", "relative_humidity_2m", "precipitation", "rain", "snowfall", "weathercode", "wind_speed_10m", "surface_pressure"]

for name, sheet in df.items():
    if sheet.index.name == "ds":
        existing_num = [col for col in numeric_cols if col in sheet.columns]
        sheet[existing_num] = sheet[existing_num].interpolate(method="time", limit_direction="both")
        df[name] = sheet

# %% [markdown]
# Построим графики чтобы посмотреть, не осталось ли выбросов.

# %%
import matplotlib.pyplot as plt

numeric_cols = ["temperature_2m", "relative_humidity_2m", "precipitation", "rain", "snowfall", "wind_speed_10m", "surface_pressure"]

for name, sheet in df.items():
    if sheet.index.name == "ds":

        for city, city_df in sheet.groupby("city"):

            for col in numeric_cols:

                plt.figure(figsize=(6, 3))
                plt.boxplot(city_df[col].dropna(), vert=False)
                plt.title(f"{name} | {city} | {col}")
                plt.show()

# %% [markdown]
# Как видно из новых графиков, выбросов данных больше нет, поэтому можно начинать проводить анализ временного ряда.

# %% [markdown]
# # Анализ временного ряда

# %% [markdown]
# По условию лабораторной работы, таргет-признак временного ряда – температура воздуха, поэтому построим визуализацию значений нашего таргет-признака для каждого города:

# %%
import matplotlib.pyplot as plt
for name, sheet in df.items():
    if sheet.index.name == "ds":
        for city, city_df in sheet.groupby("city"):
            plt.figure(figsize=(15, 5))
            plt.plot(city_df.index, city_df["temperature_2m"])
            plt.title(f"{name} — {city} — temperature_2m")
            plt.xlabel("Дата")
            plt.ylabel("Температура")
            plt.grid()
            plt.show()

# %% [markdown]
# Проверим наш временной ряд на стационарность с помощью теста Дики-Фуллера:

# %%
from statsmodels.tsa.stattools import adfuller

for name, sheet in df.items():
    if sheet.index.name == "ds":
        for city, city_df in sheet.groupby("city"):
            series = city_df["temperature_2m"].dropna()
            result = adfuller(series)
            print(f"\n{name} | {city}")
            print("ADF Statistic:", result[0])
            print("p-value:", result[1])
            print("Critical Values:")
            for key, value in result[4].items():
                print(f"{key}: {value}")
# Out:
# Лист1 | Благовещенск
# ADF Statistic: -4.045441582978291
# p-value: 0.001190393033429011
# Critical Values:
# 1%: -3.4304566692844776
# 5%: -2.861587145824668
# 10%: -2.566795094129848
#
# Лист1 | Геленджик
# ADF Statistic: -7.075497422788065
# p-value: 4.813977620695832e-10
# Critical Values:
# 1%: -3.430456667544513
# 5%: -2.8615871450556503
# 10%: -2.5667950937205233
#
# Лист2_строковые_NaN_выбросы | Москва
# ADF Statistic: -6.793137344157534
# p-value: 2.337008107810668e-09
# Critical Values:
# 1%: -3.4304566692844776
# 5%: -2.861587145824668
# 10%: -2.566795094129848
#
# Лист2_строковые_NaN_выбросы | Находка
# ADF Statistic: -5.067236267552648
# p-value: 1.6309088910920028e-05
# Critical Values:
# 1%: -3.4304567006135502
# 5%: -2.861587159671282
# 10%: -2.5667951014999764
#
# Лист3_смешанные_типы | Санкт-Петербург
# ADF Statistic: -6.420053850517736
# p-value: 1.8008596014965116e-08
# Critical Values:
# 1%: -3.4304566692844776
# 5%: -2.861587145824668
# 10%: -2.566795094129848
#
# Лист3_смешанные_типы | Сочи
# ADF Statistic: -6.630750273818276
# p-value: 5.723299597353248e-09
# Critical Values:
# 1%: -3.430456667544513
# 5%: -2.8615871450556503
# 10%: -2.5667950937205233

# %% [markdown]
# Для всех городов получены значения p-value < 0.05, что позволяет отвергнуть нулевую гипотезу о наличии единичного корня и сделать вывод о стационарности рядов по критерию ADF.

# %% [markdown]
# Декомпозируем временной ряд на тренд, сезонность и остатки:

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

from pylab import rcParams
rcParams['figure.figsize'] = 14, 10

for name, sheet in df.items():
    if sheet.index.name == "ds":
        for city, city_df in sheet.groupby("city"):
            decompose = seasonal_decompose(city_df["temperature_2m"], period=365*24)
            fig = decompose.plot()
            fig.suptitle(f"{name} | {city}", fontsize=16,y=1.02)
            fig.tight_layout()
            plt.show()

# %% [markdown]
# В результате декомпозиции временных рядов температуры данные были разделены на три основные компоненты: тренд (долгосрочное изменение температуры), сезонность (повторяющиеся годовые колебания) и остатки (случайные отклонения и выбросы). Для анализа использовался параметр period = 365 × 24, соответствующий годовому циклу для почасовых данных.
#
# Во всех городах наблюдается ярко выраженная годовая сезонность: зимой температура снижается, летом повышается. Seasonal-компонента имеет форму повторяющейся волны, отражающей смену времён года.
#
# Наиболее сильные сезонные колебания наблюдаются в Благовещенске — это связано с резко континентальным климатом. В Геленджике и Сочи сезонность выражена слабее, температуры изменяются более плавно благодаря мягкому морскому климату. Москва и Санкт-Петербург занимают промежуточное положение: сезонность хорошо заметна, но амплитуда колебаний ниже, чем в Благовещенске. В Находке температурный режим также достаточно стабильный, без резких скачков.
#
# Трендовая компонента показывает долгосрочные изменения средней температуры. В большинстве городов тренд изменяется плавно, без резких скачков, однако в Москве и Благовещенске заметны более выраженные изменения среднего температурного уровня в разные периоды наблюдений.
#
# Residual-компонента отражает случайные отклонения, шум и аномалии. Наибольшее количество выбросов наблюдается в Москве, что связано с исходными пропусками и экстремальными значениями в данных. В Сочи и Геленджике остаточные отклонения значительно меньше, что говорит о более стабильном климате.
#
# В целом декомпозиция выделила климатические особенности каждого города и показала различия между континентальным и морским типами климата.

# %% [markdown]
# После анализа тренда и сезонности проведём спектральный анализ временных рядов температуры методом быстрого преобразования Фурье.
#
# Спектральный анализ позволяет определить, какие периодические колебания присутствуют в данных и насколько они выражены. В отличие от обычного временного ряда, где температура рассматривается как функция времени, FFT переводит данные в частотную область и показывает доминирующие циклы.
#
# Для температурных данных это позволяет выявить:
#
# - суточную периодичность;
#
# - сезонные годовые колебания;
#
# - дополнительные циклы и шумовые компоненты.
#
# На данном этапе проведём анализ временного ряда температуры для города Москва.

# %%
import numpy as np
import matplotlib.pyplot as plt

city_df = df["Лист2_строковые_NaN_выбросы"]
city_df = city_df[city_df["city"] == "Москва"]

signal = city_df["temperature_2m"].dropna().values

n = len(signal)

fft_vals = np.fft.rfft(signal)
fft_freqs = np.fft.rfftfreq(n, d=1)

power = np.abs(fft_vals) ** 2

periods = 1 / fft_freqs[1:]

plt.figure(figsize=(14, 6))

plt.plot(periods, power[1:])

plt.xscale("log")

plt.xlabel("Период (часы)")
plt.ylabel("Мощность")
plt.title("Спектральный анализ температуры | Москва")

plt.grid()

plt.show()

# %% [markdown]
# Спектральный анализ временного ряда температуры Москвы показал наличие ярко выраженной годовой сезонности. На спектре наблюдается основной пик с периодом около 8760 часов (365 × 24), что соответствует годовому циклу изменения температуры.
#
# Также присутствует менее выраженный пик около 24 часов, отражающий суточные колебания температуры, связанные со сменой дня и ночи.
#
# Доминирование годовой периодичности свидетельствует о сильном влиянии сезонных климатических изменений на температурный режим Москвы. Остальные частоты имеют значительно меньшую мощность и соответствуют менее выраженным или случайным колебаниям.
#
# Проведем анализ для города Находка:

# %%
import numpy as np
import matplotlib.pyplot as plt

city_df = df["Лист2_строковые_NaN_выбросы"]
city_df = city_df[city_df["city"] == "Находка"]

signal = city_df["temperature_2m"].dropna().values

n = len(signal)

fft_vals = np.fft.rfft(signal)
fft_freqs = np.fft.rfftfreq(n, d=1)

power = np.abs(fft_vals) ** 2

periods = 1 / fft_freqs[1:]

plt.figure(figsize=(14, 6))

plt.plot(periods, power[1:])

plt.xscale("log")

plt.xlabel("Период (часы)")
plt.ylabel("Мощность")
plt.title("Спектральный анализ температуры | Находка")

plt.grid()

plt.show()

# %% [markdown]
# Спектральный анализ временного ряда температуры Находки показал наличие ярко выраженной годовой сезонности. На спектре наблюдается основной пик с периодом около 8760 часов, что соответствует годовому циклу изменения температуры.
#
# Также присутствует менее выраженная суточная периодичность с периодом около 24 часов, отражающая изменение температуры в течение суток.
#
# По сравнению с Москвой спектр Находки выглядит более сглаженным, а дополнительные пики выражены слабее. Это свидетельствует о более стабильном температурном режиме и меньшем количестве резких колебаний. Основное влияние на температурный ряд оказывает сезонная смена времён года.
#
# Проведем спектральный анализ для города Благовещенск:

# %%
import numpy as np
import matplotlib.pyplot as plt

city_df = df["Лист1"]
city_df = city_df[city_df["city"] == "Благовещенск"]

signal = city_df["temperature_2m"].dropna().values

n = len(signal)

fft_vals = np.fft.rfft(signal)
fft_freqs = np.fft.rfftfreq(n, d=1)

power = np.abs(fft_vals) ** 2

periods = 1 / fft_freqs[1:]

plt.figure(figsize=(14, 6))

plt.plot(periods, power[1:])

plt.xscale("log")

plt.xlabel("Период (часы)")
plt.ylabel("Мощность")
plt.title("Спектральный анализ температуры | Благовещенск")

plt.grid()

plt.show()

# %% [markdown]
# Спектральный анализ временного ряда температуры Благовещенска показал очень сильную годовую сезонность. На спектре наблюдается наиболее высокий пик среди рассмотренных городов с периодом около 8760 часов, что соответствует годовому циклу температуры.
#
# Также заметен суточный цикл с периодом около 24 часов, однако его мощность значительно ниже по сравнению с годовой периодичностью.
#
# Высокая мощность годового пика указывает на резко выраженную смену времён года и сильные сезонные перепады температуры. Это характерно для резко континентального климата Благовещенска, где наблюдаются очень холодные зимы и тёплое лето. Дополнительные колебания и шумовые компоненты выражены слабо по сравнению с основной сезонностью.
#
# Проведем спектральный анализ для города Геленджик:

# %%
import numpy as np
import matplotlib.pyplot as plt

city_df = df["Лист1"]
city_df = city_df[city_df["city"] == "Геленджик"]

signal = city_df["temperature_2m"].dropna().values

n = len(signal)

fft_vals = np.fft.rfft(signal)
fft_freqs = np.fft.rfftfreq(n, d=1)

power = np.abs(fft_vals) ** 2

periods = 1 / fft_freqs[1:]

plt.figure(figsize=(14, 6))

plt.plot(periods, power[1:])

plt.xscale("log")

plt.xlabel("Период (часы)")
plt.ylabel("Мощность")
plt.title("Спектральный анализ температуры | Геленджик")

plt.grid()

plt.show()

# %% [markdown]
# Спектральный анализ временного ряда температуры Геленджика показал наличие выраженной годовой сезонности. Основной пик спектра соответствует периоду около 8760 часов, что отражает годовой цикл изменения температуры.
#
# Также наблюдается суточная периодичность с периодом около 24 часов, однако её мощность значительно ниже годовой сезонности.
#
# По сравнению с Благовещенском и Москвой мощность годового пика ниже, что связано с более мягким морским климатом Геленджика и меньшей амплитудой сезонных температурных колебаний. Температурный режим города является более стабильным, а дополнительные шумовые компоненты выражены слабо.
#
# Проведем спектральный анализ для города Санкт-Петербурга:

# %%
import numpy as np
import matplotlib.pyplot as plt

city_df = df["Лист3_смешанные_типы"]
city_df = city_df[city_df["city"] == "Санкт-Петербург"]

signal = city_df["temperature_2m"].dropna().values

n = len(signal)

fft_vals = np.fft.rfft(signal)
fft_freqs = np.fft.rfftfreq(n, d=1)

power = np.abs(fft_vals) ** 2

periods = 1 / fft_freqs[1:]

plt.figure(figsize=(14, 6))

plt.plot(periods, power[1:])

plt.xscale("log")

plt.xlabel("Период (часы)")
plt.ylabel("Мощность")
plt.title("Спектральный анализ температуры | Санкт-Петербург")

plt.grid()

plt.show()

# %% [markdown]
# Спектральный анализ временного ряда температуры Санкт-Петербурга показал наличие выраженной годовой сезонности. Основной пик спектра наблюдается при периоде около 8760 часов, что соответствует годовому циклу изменения температуры.
#
# Также присутствует менее выраженная суточная периодичность с периодом около 24 часов, связанная с изменением температуры в течение суток.
#
# Мощность годового пика ниже, чем в Благовещенске, но выше, чем в Геленджике, что указывает на умеренно выраженные сезонные колебания температуры. Климат Санкт-Петербурга менее контрастный по сравнению с резко континентальными регионами, однако сезонная смена температур остаётся хорошо выраженной. Дополнительные частоты и шумовые колебания имеют небольшую мощность.
#
# Проведем спектральный анализ для города Сочи:

# %%
import numpy as np
import matplotlib.pyplot as plt

city_df = df["Лист3_смешанные_типы"]
city_df = city_df[city_df["city"] == "Сочи"]

signal = city_df["temperature_2m"].dropna().values

n = len(signal)

fft_vals = np.fft.rfft(signal)
fft_freqs = np.fft.rfftfreq(n, d=1)

power = np.abs(fft_vals) ** 2

periods = 1 / fft_freqs[1:]

plt.figure(figsize=(14, 6))

plt.plot(periods, power[1:])

plt.xscale("log")

plt.xlabel("Период (часы)")
plt.ylabel("Мощность")
plt.title("Спектральный анализ температуры | Сочи")

plt.grid()

plt.show()

# %% [markdown]
# Спектральный анализ временного ряда температуры Сочи показал наличие выраженной годовой сезонности. На спектре наблюдается основной пик с периодом около 8760 часов, соответствующий годовому циклу изменения температуры.
#
# Также присутствует менее выраженная суточная периодичность с периодом около 24 часов, связанная со сменой дня и ночи.
#
# По сравнению с другими рассмотренными городами мощность годового пика в Сочи является одной из самых низких, что объясняется мягким субтропическим климатом и относительно небольшими сезонными перепадами температуры. Температурный режим Сочи более стабильный, а дополнительные частотные колебания и шумовые компоненты выражены слабо.

# %% [markdown]
# Спектральный анализ временного ряда температуры Сочи показал наличие ярко выраженной годовой сезонности. Основной пик спектра находится около периода 8760 часов, что соответствует годовому циклу изменения температуры.
#
# Также наблюдается менее выраженная суточная периодичность около 24 часов, связанная со сменой дня и ночи.
#
# Годовой пик является доминирующей компонентой спектра, то есть именно сезонная смена времён года сильнее всего определяет динамику температуры в Сочи. При этом дополнительные частоты выражены слабо, что говорит о достаточно регулярной и устойчивой сезонной структуре ряда.

# %% [markdown]
# ### Вывод
#
# Проведённый спектральный анализ временных рядов температуры методом быстрого преобразования Фурье позволил выявить основные периодичности в данных для всех рассмотренных городов.
#
# Во всех временных рядах наблюдается ярко выраженный пик с периодом около 8760 часов, что соответствует годовому циклу изменения температуры. Это свидетельствует о доминирующем влиянии сезонной смены времён года на температурный режим всех исследуемых городов.
#
# Также во всех спектрах присутствует менее выраженный пик около 24 часов, отражающий суточную периодичность температуры, связанную со сменой дня и ночи.
#
# Наиболее выраженная годовая сезонность наблюдается в Благовещенске, что связано с резко континентальным климатом и большими сезонными перепадами температуры. В Москве и Санкт-Петербурге годовая периодичность также выражена достаточно сильно, однако амплитуда сезонных колебаний ниже.
#
# Для Геленджика и Сочи характерен более стабильный температурный режим. Несмотря на наличие ярко выраженной сезонности, температурные изменения происходят более плавно благодаря влиянию морского и субтропического климата.
#
# Дополнительные частоты и шумовые компоненты во всех рядах имеют значительно меньшую мощность по сравнению с годовым циклом, что подтверждает доминирование сезонной структуры в температурных данных.

# %% [markdown]
# # Извлечение признаков из временного ряда
#
# Для повышения качества прогнозирования из временных рядов температуры были извлечены дополнительные признаки (feature engineering). Использование дополнительных признаков позволяет модели учитывать временную структуру данных, сезонные закономерности и зависимость текущих значений температуры от предыдущих наблюдений.
#
# В рамках работы были сформированы:
# - временные признаки;
# - лаговые признаки;
# - скользящие статистики;
# - циклические признаки.
#
# Эти признаки помогают модели учитывать как краткосрочные, так и долгосрочные закономерности изменения температуры.
#
# Для построения признаков использовались окна длиной 24 и 168 часов. Окно 24 часа отражает суточную динамику температуры, а окно 168 часов — недельную историю временного ряда. На основе этих окон были построены лаговые признаки и скользящие статистики.

# %%
import numpy as np

for name, sheet in df.items():
    if sheet.index.name == "ds" and "city" in sheet.columns:
        parts = []
        for city, city_df in sheet.groupby("city"):
            city_df = city_df.sort_index().copy()
            city_df["hour"] = city_df.index.hour
            city_df["month"] = city_df.index.month
            city_df["dayofweek"] = city_df.index.dayofweek
            city_df["season"] = city_df["month"].map({12: "winter", 1: "winter", 2: "winter", 3: "spring", 4: "spring", 5: "spring", 6: "summer", 7: "summer", 8: "summer", 9: "autumn", 10: "autumn", 11: "autumn"})
            city_df["lag_24"] = city_df["temperature_2m"].shift(24)
            city_df["lag_168"] = city_df["temperature_2m"].shift(168)
            city_df["rolling_mean_24"] = city_df["temperature_2m"].shift(1).rolling(24).mean()
            city_df["rolling_std_24"] = city_df["temperature_2m"].shift(1).rolling(24).std()
            city_df["month_sin"] = np.sin(2 * np.pi * city_df["month"] / 12)
            city_df["month_cos"] = np.cos(2 * np.pi * city_df["month"] / 12)
            parts.append(city_df)
        df[name] = pd.concat(parts).sort_index()

for name, sheet in df.items():
    if sheet.index.name == "ds":
        df[name] = sheet.dropna()

# %% [markdown]
# В результате feature engineering были сформированы дополнительные признаки, отражающие временную структуру и сезонные закономерности временного ряда. Были добавлены временные признаки (час, месяц, день недели, сезон), лаговые признаки, характеризующие зависимость температуры от предыдущих значений, а также скользящие статистики и циклическое кодирование месяцев. Полученные признаки могут использоваться для последующего обучения моделей прогнозирования температуры.

# %% [markdown]
# # Построение моделей прогнозирования
#
# Данные разделялись хронологически на train, validation и test без перемешивания наблюдений. Такой подход позволяет избежать утечки информации из будущего и корректно оценить качество моделей временных рядов.
#
# После предварительной обработки временных рядов и извлечения признаков были построены модели машинного обучения для прогнозирования температуры.
#
# В рамках работы рассматриваются:
# - дерево решений
# - случайный лес
# - бустинг
#
# Данные модели позволяют учитывать нелинейные зависимости, сезонность и влияние предыдущих значений температуры на будущие наблюдения.
#
# Для обучения моделей используются извлечённые ранее временные, лаговые и статистические признаки. В дальнейшем планируется подбор гиперпараметров с помощью библиотеки Optuna и сравнение различных стратегий прогнозирования.

# %% [markdown]
# Создадим модель на каждый горизонт для каждого города:

# %%
import optuna
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.metrics import mean_absolute_error

features = ["hour", "month", "dayofweek", "lag_24", "lag_168", "rolling_mean_24", "rolling_std_24", "month_sin", "month_cos"]
horizons = list(range(1, 169))

# сплит на train, val, test
def split_data(city_df, target_col):
    city_df = city_df.sort_index().dropna(subset=features + [target_col])
    train_end = int(len(city_df) * 0.7)
    val_end = int(len(city_df) * 0.85)
    X = city_df[features]
    y = city_df[target_col]
    return X.iloc[:train_end], X.iloc[train_end:val_end], X.iloc[val_end:], y.iloc[:train_end], y.iloc[train_end:val_end], y.iloc[val_end:]

# создаём модель по имени
def get_model(model_name, params):
    if model_name == "Decision Tree":
        return DecisionTreeRegressor(**params, random_state=44)
    if model_name == "Random Forest":
        return RandomForestRegressor(**params, random_state=44, n_jobs=-1)
    if model_name == "Gradient Boosting":
        return GradientBoostingRegressor(**params, random_state=44)

# подбираем лучшие гиперпараметры через Optuna
def tune_model(model_name, X_train, X_val, y_train, y_val, n_trials=5):
    # функция качества модели, много раз вызывает objective() с разными параметрами
    def objective(trial):
        if model_name == "Decision Tree":
            params = {"max_depth": trial.suggest_int("max_depth", 3, 20), "min_samples_leaf": trial.suggest_int("min_samples_leaf", 1, 30)}
        elif model_name == "Random Forest":
            params = {"n_estimators": trial.suggest_int("n_estimators", 50, 150), "max_depth": trial.suggest_int("max_depth", 3, 20), "min_samples_leaf": trial.suggest_int("min_samples_leaf", 1, 30)}
        else:
            params = {"n_estimators": trial.suggest_int("n_estimators", 50, 200), "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.2), "max_depth": trial.suggest_int("max_depth", 2, 8)}
        model = get_model(model_name, params)
        model.fit(X_train, y_train)
        return mean_absolute_error(y_val, model.predict(X_val))
    study = optuna.create_study(direction="minimize")
    study.optimize(objective, n_trials=n_trials)
    return study.best_params

results = []
models = ["Decision Tree", "Random Forest", "Gradient Boosting"]

for name, sheet in df.items():
    if sheet.index.name == "ds" and "city" in sheet.columns:
        for city, city_df in sheet.groupby("city"):
            city_df = city_df.sort_index().copy()
            for h in horizons:
                city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
            for model_name in models:
                for h in horizons:
                    target_col = f"target_{h}"
                    X_train, X_val, X_test, y_train, y_val, y_test = split_data(city_df, target_col)
                    best_params = tune_model(model_name, X_train, X_val, y_train, y_val)
                    model = get_model(model_name, best_params)
                    model.fit(pd.concat([X_train, X_val]), pd.concat([y_train, y_val]))
                    y_pred = model.predict(X_test)
                    results.append({"sheet": name, "city": city, "model": model_name, "strategy": "direct", "horizon": h, "MAE": mean_absolute_error(y_test, y_pred), "params": best_params})
                    pd.DataFrame(results).to_csv("direct_results_progress.csv", index=False)

results_df = pd.DataFrame(results)
results_df.to_csv("direct_results_final.csv", index=False)
results_df
# Out:
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# /var/folders/fp/s4yv3j492yggc4pldt8f4kpw0000gn/T/ipykernel_996/3614471596.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   city_df[f"target_{h}"] = city_df["temperature_2m"].shift(-h)
# [I 2026-05-10 14:24:21,195] A new study created in memory with name: no-name-075e90a9-61dd-4932-bd29-bdb80efa173c
# [I 2026-05-10 14:24:21,320] Trial 0 finished with value: 2.6031163621363556 and parameters: {'max_depth': 7, 'min_samples_leaf': 30}. Best is trial 0 with value: 2.6031163621363556.
# [I 2026-05-10 14:24:21,487] Trial 1 finished with value: 2.4038915012807505 and parameters: {'max_depth': 10, 'min_samples_leaf': 20}. Best is trial 1 with value: 2.4038915012807505.
# [I 2026-05-10 14:24:21,545] Trial 2 finished with value: 3.5369713300039924 and parameters: {'max_depth': 3, 'min_samples_leaf': 28}. Best is trial 1 with value: 2.4038915012807505.
# [I 2026-05-10 14:24:21,729] Trial 3 finished with value: 2.4267141341494627 and parameters: {'max_depth': 11, 'min_samples_leaf': 6}. Best is trial 1 with value: 2.4038915012807505.
# [I 2026-05-10 14:24:21,988] Trial 4 finished with value: 2.839065969960847 and parameters: {'max_depth': 16, 'min_samples_leaf': 1}. Best is trial 1 with value: 2.4038915012807505.
# [I 2026-05-10 14:24:22,236] A new study created in memory with name: no-name-9b13b1fc-0356-4b73-a8bd-2fda9e4928ad
# [I 2026-05-10 14:24:22,462] Trial 0 finished with value: 2.5595320475429886 and parameters: {'max_depth': 19, 'min_samples_leaf': 7}. Best is trial 0 with value: 2.5595320475429886.
# [I 2026-05-10 14:24:22,590] Trial 1 finished with value: 2.5747529937155837 and parameters: {'max_depth': 7, 'min_samples_leaf': 30}. Best is trial 0 with value: 2.5595320475429886.
# [I 2026-05-10 14:24:22,652] Trial 2 finished with value: 3.7045332697886324 and parameters: {'max_depth': 3, 'min_samples_leaf': 1}. Best is trial 0 with value: 2.5595320475429886.
# [I 2026-05-10 14:24:22,860] Trial 3 finished with value: 2.4628211191517484 and parameters: {'max_depth': 15, 'min_samples_leaf': 11}. Best is trial 3 with value: 2.4628211191517484.
# [I 2026-05-10 14:24:23,087] Trial 4 finished with value: 2.8774727528370847 and parameters: {'max_depth': 14, 'min_samples_leaf': 1}. Best is trial 3 with value: 2.4628211191517484.
# [I 2026-05-10 14:24:23,379] A new study created in memory with name: no-name-a54570bc-c55b-4a26-9250-07a3cbb1863a
# [I 2026-05-10 14:24:23,557] Trial 0 finished with value: 2.4470144427614833 and parameters: {'max_depth': 11, 'min_samples_leaf': 30}. Best is trial 0 with value: 2.4470144427614833.
# [I 2026-05-10 14:24:23,766] Trial 1 finished with value: 2.6147447427731136 and parameters: {'max_depth': 13, 'min_samples_leaf': 6}. Best is trial 0 with value: 2.4470144427614833.
# [I 2026-05-10 14:24:23,955] Trial 2 finished with value: 2.4743742923340406 and parameters: {'max_depth': 15, 'min_samples_leaf': 29}. Best is trial 0 with value: 2.4470144427614833.
# [I 2026-05-10 14:24:24,112] Trial 3 finished with value: 2.474644472094198 and parameters: {'max_depth': 9, 'min_samples_leaf': 20}. Best is trial 0 with value: 2.4470144427614833.
# [I 2026-05-10 14:24:24,312] Trial 4 finished with value: 2.528629105913127 and parameters: {'max_depth': 18, 'min_samples_leaf': 19}. Best is trial 0 with value: 2.4470144427614833.
# [I 2026-05-10 14:24:24,564] A new study created in memory with name: no-name-48adfc79-76e6-47e6-982b-44e6a92d11f6
# [I 2026-05-10 14:24:24,688] Trial 0 finished with value: 2.611701123192872 and parameters: {'max_depth': 7, 'min_samples_leaf': 9}. Best is trial 0 with value: 2.611701123192872.
# [I 2026-05-10 14:24:24,826] Trial 1 finished with value: 2.525043256913801 and parameters: {'max_depth': 8, 'min_samples_leaf': 27}. Best is trial 1 with value: 2.525043256913801.
# [I 2026-05-10 14:24:24,949] Trial 2 finished with value: 2.6078724487708915 and parameters: {'max_depth': 7, 'min_samples_leaf': 27}. Best is trial 1 with value: 2.525043256913801.
# [I 2026-05-10 14:24:25,138] Trial 3 finished with value: 2.535005073577725 and parameters: {'max_depth': 18, 'min_samples_leaf': 24}. Best is trial 1 with value: 2.525043256913801.
# [I 2026-05-10 14:24:25,357] Trial 4 finished with value: 2.764054801913737 and parameters: {'max_depth': 19, 'min_samples_leaf': 8}. Best is trial 1 with value: 2.525043256913801.
# [I 2026-05-10 14:24:25,560] A new study created in memory with name: no-name-5d672897-1864-4aa7-869c-f7ff81847b5d
# [I 2026-05-10 14:24:25,766] Trial 0 finished with value: 2.7972486386632704 and parameters: {'max_depth': 13, 'min_samples_leaf': 4}. Best is trial 0 with value: 2.7972486386632704.
# [I 2026-05-10 14:24:25,965] Trial 1 finished with value: 2.674299088442282 and parameters: {'max_depth': 16, 'min_samples_leaf': 16}. Best is trial 1 with value: 2.674299088442282.
# [I 2026-05-10 14:24:26,040] Trial 2 finished with value: 3.6387486757399663 and parameters: {'max_depth': 4, 'min_samples_leaf': 14}. Best is trial 1 with value: 2.674299088442282.
# [I 2026-05-10 14:24:26,243] Trial 3 finished with value: 2.76261889858834 and parameters: {'max_depth': 13, 'min_samples_leaf': 7}. Best is trial 1 with value: 2.674299088442282.
# [I 2026-05-10 14:24:26,335] Trial 4 finished with value: 3.2101913679608893 and parameters: {'max_depth': 5, 'min_samples_leaf': 5}. Best is trial 1 with value: 2.674299088442282.
# [I 2026-05-10 14:24:26,618] A new study created in memory with name: no-name-b2697db9-11ca-40cf-b13b-dd087b1f03a7
# [I 2026-05-10 14:24:26,727] Trial 0 finished with value: 2.8939613614091324 and parameters: {'max_depth': 6, 'min_samples_leaf': 20}. Best is trial 0 with value: 2.8939613614091324.
# [I 2026-05-10 14:24:26,785] Trial 1 finished with value: 3.9752242906201554 and parameters: {'max_depth': 3, 'min_samples_leaf': 22}. Best is trial 0 with value: 2.8939613614091324.
# [I 2026-05-10 14:24:26,925] Trial 2 finished with value: 2.7077415071971394 and parameters: {'max_depth': 8, 'min_samples_leaf': 7}. Best is trial 2 with value: 2.7077415071971394.
# [I 2026-05-10 14:24:27,135] Trial 3 finished with value: 2.8320756194562695 and parameters: {'max_depth': 18, 'min_samples_leaf': 11}. Best is trial 2 with value: 2.7077415071971394.
# [I 2026-05-10 14:24:27,363] Trial 4 finished with value: 2.9660784368890054 and parameters: {'max_depth': 19, 'min_samples_leaf': 6}. Best is trial 2 with value: 2.7077415071971394.
# [I 2026-05-10 14:24:27,566] A new study created in memory with name: no-name-65aada70-deff-4d7e-94be-78b26a7d893d
# [I 2026-05-10 14:24:27,755] Trial 0 finished with value: 2.6789496159110846 and parameters: {'max_depth': 17, 'min_samples_leaf': 28}. Best is trial 0 with value: 2.6789496159110846.
# [I 2026-05-10 14:24:27,896] Trial 1 finished with value: 2.721444758694493 and parameters: {'max_depth': 8, 'min_samples_leaf': 8}. Best is trial 0 with value: 2.6789496159110846.
# [I 2026-05-10 14:24:28,077] Trial 2 finished with value: 2.736213027581584 and parameters: {'max_depth': 11, 'min_samples_leaf': 6}. Best is trial 0 with value: 2.6789496159110846.
# [I 2026-05-10 14:24:28,270] Trial 3 finished with value: 2.7562456711228136 and parameters: {'max_depth': 19, 'min_samples_leaf': 20}. Best is trial 0 with value: 2.6789496159110846.
# [I 2026-05-10 14:24:28,448] Trial 4 finished with value: 2.6951168539260117 and parameters: {'max_depth': 11, 'min_samples_leaf': 18}. Best is trial 0 with value: 2.6789496159110846.
# [I 2026-05-10 14:24:28,721] A new study created in memory with name: no-name-31f2dd73-65dd-43c5-8512-32c8e594b240
# [I 2026-05-10 14:24:28,833] Trial 0 finished with value: 2.927048189544154 and parameters: {'max_depth': 6, 'min_samples_leaf': 3}. Best is trial 0 with value: 2.927048189544154.
# [I 2026-05-10 14:24:28,957] Trial 1 finished with value: 2.8097185144319137 and parameters: {'max_depth': 7, 'min_samples_leaf': 22}. Best is trial 1 with value: 2.8097185144319137.
# [I 2026-05-10 14:24:29,032] Trial 2 finished with value: 3.4271100033806325 and parameters: {'max_depth': 4, 'min_samples_leaf': 4}. Best is trial 1 with value: 2.8097185144319137.
# [I 2026-05-10 14:24:29,233] Trial 3 finished with value: 2.8522886207024905 and parameters: {'max_depth': 13, 'min_samples_leaf': 10}. Best is trial 1 with value: 2.8097185144319137.
# [I 2026-05-10 14:24:29,416] Trial 4 finished with value: 2.8016107206217375 and parameters: {'max_depth': 11, 'min_samples_leaf': 6}. Best is trial 4 with value: 2.8016107206217375.
# [I 2026-05-10 14:24:29,676] A new study created in memory with name: no-name-646f947e-2370-4f03-8ad1-1a7bc8e5bd9c
# [I 2026-05-10 14:24:29,871] Trial 0 finished with value: 2.943430452219103 and parameters: {'max_depth': 12, 'min_samples_leaf': 6}. Best is trial 0 with value: 2.943430452219103.
# [I 2026-05-10 14:24:29,945] Trial 1 finished with value: 3.4172706560824353 and parameters: {'max_depth': 4, 'min_samples_leaf': 17}. Best is trial 0 with value: 2.943430452219103.
# [I 2026-05-10 14:24:30,084] Trial 2 finished with value: 2.799958449422363 and parameters: {'max_depth': 8, 'min_samples_leaf': 25}. Best is trial 2 with value: 2.799958449422363.
# [I 2026-05-10 14:24:30,277] Trial 3 finished with value: 2.943430452219103 and parameters: {'max_depth': 12, 'min_samples_leaf': 6}. Best is trial 2 with value: 2.799958449422363.
# [I 2026-05-10 14:24:30,474] Trial 4 finished with value: 2.8834370880320375 and parameters: {'max_depth': 20, 'min_samples_leaf': 18}. Best is trial 2 with value: 2.799958449422363.
# [I 2026-05-10 14:24:30,678] A new study created in memory with name: no-name-04a45d54-e52d-4dec-bccc-940073ab118d
# [I 2026-05-10 14:24:30,803] Trial 0 finished with value: 2.959476308266917 and parameters: {'max_depth': 6, 'min_samples_leaf': 8}. Best is trial 0 with value: 2.959476308266917.
# [I 2026-05-10 14:24:30,982] Trial 1 finished with value: 2.820714555629166 and parameters: {'max_depth': 11, 'min_samples_leaf': 24}. Best is trial 1 with value: 2.820714555629166.
# [I 2026-05-10 14:24:31,172] Trial 2 finished with value: 2.8676169370367193 and parameters: {'max_depth': 17, 'min_samples_leaf': 26}. Best is trial 1 with value: 2.820714555629166.
# [I 2026-05-10 14:24:31,366] Trial 3 finished with value: 2.9741304560484303 and parameters: {'max_depth': 12, 'min_samples_leaf': 5}. Best is trial 1 with value: 2.820714555629166.
# [I 2026-05-10 14:24:31,561] Trial 4 finished with value: 2.8794833510626963 and parameters: {'max_depth': 19, 'min_samples_leaf': 20}. Best is trial 1 with value: 2.820714555629166.
# [I 2026-05-10 14:24:31,811] A new study created in memory with name: no-name-8274b1ef-7e6f-4d16-91d2-948872f8ab7c
# [I 2026-05-10 14:24:32,015] Trial 0 finished with value: 2.9757750757897092 and parameters: {'max_depth': 17, 'min_samples_leaf': 18}. Best is trial 0 with value: 2.9757750757897092.
# [I 2026-05-10 14:24:32,089] Trial 1 finished with value: 3.4501698222390313 and parameters: {'max_depth': 4, 'min_samples_leaf': 17}. Best is trial 0 with value: 2.9757750757897092.
# [I 2026-05-10 14:24:32,269] Trial 2 finished with value: 2.916681564507913 and parameters: {'max_depth': 11, 'min_samples_leaf': 11}. Best is trial 2 with value: 2.916681564507913.
# [I 2026-05-10 14:24:32,328] Trial 3 finished with value: 4.1061121141444525 and parameters: {'max_depth': 3, 'min_samples_leaf': 29}. Best is trial 2 with value: 2.916681564507913.
# [I 2026-05-10 14:24:32,538] Trial 4 finished with value: 3.1593503025427805 and parameters: {'max_depth': 13, 'min_samples_leaf': 2}. Best is trial 2 with value: 2.916681564507913.
# [I 2026-05-10 14:24:32,793] A new study created in memory with name: no-name-a77616b7-7f54-43d0-a891-1b6f8e88af47
# [I 2026-05-10 14:24:32,920] Trial 0 finished with value: 2.927084603216308 and parameters: {'max_depth': 7, 'min_samples_leaf': 22}. Best is trial 0 with value: 2.927084603216308.
# [I 2026-05-10 14:24:33,115] Trial 1 finished with value: 2.9864371886208043 and parameters: {'max_depth': 15, 'min_samples_leaf': 28}. Best is trial 0 with value: 2.927084603216308.
# [I 2026-05-10 14:24:33,378] Trial 2 finished with value: 3.6124640687484355 and parameters: {'max_depth': 17, 'min_samples_leaf': 1}. Best is trial 0 with value: 2.927084603216308.
# [I 2026-05-10 14:24:33,531] Trial 3 finished with value: 2.9498288575182303 and parameters: {'max_depth': 9, 'min_samples_leaf': 4}. Best is trial 0 with value: 2.927084603216308.
# [I 2026-05-10 14:24:33,744] Trial 4 finished with value: 3.270454172889961 and parameters: {'max_depth': 14, 'min_samples_leaf': 6}. Best is trial 0 with value: 2.927084603216308.
# [I 2026-05-10 14:24:33,928] A new study created in memory with name: no-name-dd14c0fa-de4d-4487-819d-8a1ac4d1e1cf
# [I 2026-05-10 14:24:34,066] Trial 0 finished with value: 2.969400443636374 and parameters: {'max_depth': 8, 'min_samples_leaf': 14}. Best is trial 0 with value: 2.969400443636374.
# [I 2026-05-10 14:24:34,159] Trial 1 finished with value: 3.34137953544262 and parameters: {'max_depth': 5, 'min_samples_leaf': 20}. Best is trial 0 with value: 2.969400443636374.
# [I 2026-05-10 14:24:34,269] Trial 2 finished with value: 3.1203871257968783 and parameters: {'max_depth': 6, 'min_samples_leaf': 11}. Best is trial 0 with value: 2.969400443636374.
# [I 2026-05-10 14:24:34,462] Trial 3 finished with value: 2.9533244122852156 and parameters: {'max_depth': 15, 'min_samples_leaf': 26}. Best is trial 3 with value: 2.9533244122852156.
# [I 2026-05-10 14:24:34,635] Trial 4 finished with value: 3.0252788372764057 and parameters: {'max_depth': 10, 'min_samples_leaf': 3}. Best is trial 3 with value: 2.9533244122852156.
# [I 2026-05-10 14:24:34,908] A new study created in memory with name: no-name-b91c8984-94a5-46ff-9f30-afd5be0e6f55
# [I 2026-05-10 14:24:35,107] Trial 0 finished with value: 3.0886840001697333 and parameters: {'max_depth': 14, 'min_samples_leaf': 15}. Best is trial 0 with value: 3.0886840001697333.
# [I 2026-05-10 14:24:35,259] Trial 1 finished with value: 2.982221732613119 and parameters: {'max_depth': 9, 'min_samples_leaf': 30}. Best is trial 1 with value: 2.982221732613119.
# [I 2026-05-10 14:24:35,514] Trial 2 finished with value: 3.6052761228638905 and parameters: {'max_depth': 19, 'min_samples_leaf': 3}. Best is trial 1 with value: 2.982221732613119.
# [I 2026-05-10 14:24:35,743] Trial 3 finished with value: 3.349316983800221 and parameters: {'max_depth': 18, 'min_samples_leaf': 7}. Best is trial 1 with value: 2.982221732613119.
# [I 2026-05-10 14:24:35,932] Trial 4 finished with value: 3.0283985526456236 and parameters: {'max_depth': 15, 'min_samples_leaf': 29}. Best is trial 1 with value: 2.982221732613119.
# [I 2026-05-10 14:24:36,150] A new study created in memory with name: no-name-1a19507b-15bf-476e-b61c-b21c8ecbffaa
# [I 2026-05-10 14:24:36,437] Trial 0 finished with value: 3.886923136056546 and parameters: {'max_depth': 20, 'min_samples_leaf': 1}. Best is trial 0 with value: 3.886923136056546.
# [I 2026-05-10 14:24:36,638] Trial 1 finished with value: 3.0239194152015942 and parameters: {'max_depth': 19, 'min_samples_leaf': 29}. Best is trial 1 with value: 3.0239194152015942.
# [I 2026-05-10 14:24:36,821] Trial 2 finished with value: 3.0954848323322763 and parameters: {'max_depth': 11, 'min_samples_leaf': 7}. Best is trial 1 with value: 3.0239194152015942.
# [I 2026-05-10 14:24:36,944] Trial 3 finished with value: 3.1051228444150896 and parameters: {'max_depth': 7, 'min_samples_leaf': 6}. Best is trial 1 with value: 3.0239194152015942.
# [I 2026-05-10 14:24:37,124] Trial 4 finished with value: 3.0207176578385675 and parameters: {'max_depth': 11, 'min_samples_leaf': 14}. Best is trial 4 with value: 3.0207176578385675.
# [I 2026-05-10 14:24:37,378] A new study created in memory with name: no-name-2190a14f-826b-45d8-8b32-f177568c3b38
# [I 2026-05-10 14:24:37,517] Trial 0 finished with value: 3.1085188107851716 and parameters: {'max_depth': 8, 'min_samples_leaf': 11}. Best is trial 0 with value: 3.1085188107851716.
# [I 2026-05-10 14:24:37,655] Trial 1 finished with value: 3.1080762728358216 and parameters: {'max_depth': 8, 'min_samples_leaf': 10}. Best is trial 1 with value: 3.1080762728358216.
# [I 2026-05-10 14:24:37,868] Trial 2 finished with value: 3.2036469815430646 and parameters: {'max_depth': 17, 'min_samples_leaf': 14}. Best is trial 1 with value: 3.1080762728358216.
# [I 2026-05-10 14:24:38,039] Trial 3 finished with value: 3.112263268398073 and parameters: {'max_depth': 10, 'min_samples_leaf': 5}. Best is trial 1 with value: 3.1080762728358216.
# [I 2026-05-10 14:24:38,221] Trial 4 finished with value: 3.05732985426669 and parameters: {'max_depth': 12, 'min_samples_leaf': 26}. Best is trial 4 with value: 3.05732985426669.
# [I 2026-05-10 14:24:38,479] A new study created in memory with name: no-name-33eb72a1-52e8-4835-8344-06e5f372882d
# [I 2026-05-10 14:24:38,670] Trial 0 finished with value: 3.0986463176271215 and parameters: {'max_depth': 15, 'min_samples_leaf': 28}. Best is trial 0 with value: 3.0986463176271215.
# [I 2026-05-10 14:24:38,838] Trial 1 finished with value: 3.0148130784148126 and parameters: {'max_depth': 10, 'min_samples_leaf': 27}. Best is trial 1 with value: 3.0148130784148126.
# [I 2026-05-10 14:24:39,082] Trial 2 finished with value: 3.5793059818617623 and parameters: {'max_depth': 17, 'min_samples_leaf': 3}. Best is trial 1 with value: 3.0148130784148126.
# [I 2026-05-10 14:24:39,140] Trial 3 finished with value: 4.31516023734785 and parameters: {'max_depth': 3, 'min_samples_leaf': 21}. Best is trial 1 with value: 3.0148130784148126.
# [I 2026-05-10 14:24:39,282] Trial 4 finished with value: 3.0927762589832994 and parameters: {'max_depth': 8, 'min_samples_leaf': 1}. Best is trial 1 with value: 3.0148130784148126.
# [I 2026-05-10 14:24:39,517] A new study created in memory with name: no-name-c861bf74-cc1d-433d-999b-693fa6adb0d3
# [I 2026-05-10 14:24:39,731] Trial 0 finished with value: 3.3416606093748698 and parameters: {'max_depth': 16, 'min_samples_leaf': 11}. Best is trial 0 with value: 3.3416606093748698.
# [I 2026-05-10 14:24:39,807] Trial 1 finished with value: 3.7277370838027952 and parameters: {'max_depth': 4, 'min_samples_leaf': 3}. Best is trial 0 with value: 3.3416606093748698.
# [I 2026-05-10 14:24:39,958] Trial 2 finished with value: 3.0559601704803443 and parameters: {'max_depth': 9, 'min_samples_leaf': 27}. Best is trial 2 with value: 3.0559601704803443.
# ...
# [I 2026-05-11 06:01:27,881] Trial 2 finished with value: 2.665239454170418 and parameters: {'n_estimators': 70, 'learning_rate': 0.09185397888335066, 'max_depth': 2}. Best is trial 0 with value: 2.6600297932413532.
# [I 2026-05-11 06:01:33,146] Trial 3 finished with value: 2.684075327999386 and parameters: {'n_estimators': 178, 'learning_rate': 0.09469745595121694, 'max_depth': 3}. Best is trial 0 with value: 2.6600297932413532.
# [I 2026-05-11 06:01:39,598] Trial 4 finished with value: 2.7859545663525793 and parameters: {'n_estimators': 132, 'learning_rate': 0.18100710517342788, 'max_depth': 5}. Best is trial 0 with value: 2.6600297932413532.
# [I 2026-05-11 06:01:40,853] A new study created in memory with name: no-name-cb07f084-5447-46b4-bdc4-8f15196a17ed
# [I 2026-05-11 06:01:43,926] Trial 0 finished with value: 2.8909006500105643 and parameters: {'n_estimators': 81, 'learning_rate': 0.026789056971655196, 'max_depth': 4}. Best is trial 0 with value: 2.8909006500105643.
# [I 2026-05-11 06:01:49,587] Trial 1 finished with value: 2.671998999635769 and parameters: {'n_estimators': 147, 'learning_rate': 0.03615822745423133, 'max_depth': 4}. Best is trial 1 with value: 2.671998999635769.
# [I 2026-05-11 06:01:59,069] Trial 2 finished with value: 2.817469012675248 and parameters: {'n_estimators': 142, 'learning_rate': 0.08261961144422869, 'max_depth': 7}. Best is trial 1 with value: 2.671998999635769.
# [I 2026-05-11 06:02:08,813] Trial 3 finished with value: 2.8164913133890765 and parameters: {'n_estimators': 168, 'learning_rate': 0.10727814274073909, 'max_depth': 6}. Best is trial 1 with value: 2.671998999635769.
# [I 2026-05-11 06:02:14,817] Trial 4 finished with value: 2.685674484161942 and parameters: {'n_estimators': 155, 'learning_rate': 0.050360183917296616, 'max_depth': 4}. Best is trial 1 with value: 2.671998999635769.
# [I 2026-05-11 06:02:21,697] A new study created in memory with name: no-name-3c82eedd-4bbd-4bf9-8062-a74c9401024f
# [I 2026-05-11 06:02:24,053] Trial 0 finished with value: 2.7577396916609316 and parameters: {'n_estimators': 81, 'learning_rate': 0.03973518232023523, 'max_depth': 3}. Best is trial 0 with value: 2.7577396916609316.
# [I 2026-05-11 06:02:37,427] Trial 1 finished with value: 2.9542234945867354 and parameters: {'n_estimators': 173, 'learning_rate': 0.1704225576823663, 'max_depth': 8}. Best is trial 0 with value: 2.7577396916609316.
# [I 2026-05-11 06:02:45,155] Trial 2 finished with value: 2.826716957797569 and parameters: {'n_estimators': 158, 'learning_rate': 0.17530857102673322, 'max_depth': 5}. Best is trial 0 with value: 2.7577396916609316.
# [I 2026-05-11 06:02:49,271] Trial 3 finished with value: 2.7116614904295435 and parameters: {'n_estimators': 139, 'learning_rate': 0.15118175059738778, 'max_depth': 3}. Best is trial 3 with value: 2.7116614904295435.
# [I 2026-05-11 06:02:51,432] Trial 4 finished with value: 2.6710206466681594 and parameters: {'n_estimators': 56, 'learning_rate': 0.09792297399134348, 'max_depth': 4}. Best is trial 4 with value: 2.6710206466681594.
# [I 2026-05-11 06:02:54,081] A new study created in memory with name: no-name-fea87814-5309-45ff-8cc3-8e06cdbf8968
# [I 2026-05-11 06:03:08,027] Trial 0 finished with value: 2.8442507080698407 and parameters: {'n_estimators': 184, 'learning_rate': 0.06884582961626629, 'max_depth': 8}. Best is trial 0 with value: 2.8442507080698407.
# [I 2026-05-11 06:03:09,718] Trial 1 finished with value: 2.7201789345204435 and parameters: {'n_estimators': 85, 'learning_rate': 0.05906139548581088, 'max_depth': 2}. Best is trial 1 with value: 2.7201789345204435.
# [I 2026-05-11 06:03:16,251] Trial 2 finished with value: 2.7219392880304922 and parameters: {'n_estimators': 135, 'learning_rate': 0.0687206586478312, 'max_depth': 5}. Best is trial 1 with value: 2.7201789345204435.
# [I 2026-05-11 06:03:21,385] Trial 3 finished with value: 2.774189160827067 and parameters: {'n_estimators': 105, 'learning_rate': 0.1879174843183099, 'max_depth': 5}. Best is trial 1 with value: 2.7201789345204435.
# [I 2026-05-11 06:03:26,396] Trial 4 finished with value: 2.781364587153532 and parameters: {'n_estimators': 128, 'learning_rate': 0.19592220835487603, 'max_depth': 4}. Best is trial 1 with value: 2.7201789345204435.
# [I 2026-05-11 06:03:28,478] A new study created in memory with name: no-name-c9885615-c4dc-4a02-a582-0d171a29508f
# [I 2026-05-11 06:03:31,989] Trial 0 finished with value: 2.670991274888892 and parameters: {'n_estimators': 119, 'learning_rate': 0.07291066453925808, 'max_depth': 3}. Best is trial 0 with value: 2.670991274888892.
# [I 2026-05-11 06:03:36,834] Trial 1 finished with value: 2.8920155662860974 and parameters: {'n_estimators': 64, 'learning_rate': 0.18514288288471017, 'max_depth': 8}. Best is trial 0 with value: 2.670991274888892.
# [I 2026-05-11 06:03:38,579] Trial 2 finished with value: 2.6523917821581664 and parameters: {'n_estimators': 88, 'learning_rate': 0.09798374341857852, 'max_depth': 2}. Best is trial 2 with value: 2.6523917821581664.
# [I 2026-05-11 06:03:45,328] Trial 3 finished with value: 2.865791788383336 and parameters: {'n_estimators': 89, 'learning_rate': 0.13465461051472877, 'max_depth': 8}. Best is trial 2 with value: 2.6523917821581664.
# [I 2026-05-11 06:03:55,675] Trial 4 finished with value: 2.750321137495529 and parameters: {'n_estimators': 185, 'learning_rate': 0.03082913616705512, 'max_depth': 6}. Best is trial 2 with value: 2.6523917821581664.
# [I 2026-05-11 06:03:57,824] A new study created in memory with name: no-name-9f7e9698-675d-4c9b-909a-952beee7f95b
# [I 2026-05-11 06:04:01,578] Trial 0 finished with value: 2.856695424967978 and parameters: {'n_estimators': 50, 'learning_rate': 0.19051142392841763, 'max_depth': 8}. Best is trial 0 with value: 2.856695424967978.
# [I 2026-05-11 06:04:12,046] Trial 1 finished with value: 2.8607976312174044 and parameters: {'n_estimators': 179, 'learning_rate': 0.15541169411444114, 'max_depth': 6}. Best is trial 0 with value: 2.856695424967978.
# [I 2026-05-11 06:04:14,656] Trial 2 finished with value: 2.6456003390355387 and parameters: {'n_estimators': 131, 'learning_rate': 0.09142027031936267, 'max_depth': 2}. Best is trial 2 with value: 2.6456003390355387.
# [I 2026-05-11 06:04:17,929] Trial 3 finished with value: 2.6645779596004866 and parameters: {'n_estimators': 111, 'learning_rate': 0.07896016253005843, 'max_depth': 3}. Best is trial 2 with value: 2.6456003390355387.
# [I 2026-05-11 06:04:22,264] Trial 4 finished with value: 2.671744080845073 and parameters: {'n_estimators': 147, 'learning_rate': 0.0846387748878658, 'max_depth': 3}. Best is trial 2 with value: 2.6456003390355387.
# [I 2026-05-11 06:04:25,448] A new study created in memory with name: no-name-3c3887bb-c656-4f1f-af2d-9515772bf6b7
# [I 2026-05-11 06:04:29,117] Trial 0 finished with value: 2.692562643754355 and parameters: {'n_estimators': 124, 'learning_rate': 0.12901258177586242, 'max_depth': 3}. Best is trial 0 with value: 2.692562643754355.
# [I 2026-05-11 06:04:34,066] Trial 1 finished with value: 2.733186295613513 and parameters: {'n_estimators': 126, 'learning_rate': 0.17941270985858837, 'max_depth': 4}. Best is trial 0 with value: 2.692562643754355.
# [I 2026-05-11 06:04:39,955] Trial 2 finished with value: 2.7176411820043436 and parameters: {'n_estimators': 122, 'learning_rate': 0.0805216001162348, 'max_depth': 5}. Best is trial 0 with value: 2.692562643754355.
# [I 2026-05-11 06:04:43,149] Trial 3 finished with value: 2.815651698394342 and parameters: {'n_estimators': 58, 'learning_rate': 0.04013113625013572, 'max_depth': 6}. Best is trial 0 with value: 2.692562643754355.
# [I 2026-05-11 06:04:45,526] Trial 4 finished with value: 2.69383911303488 and parameters: {'n_estimators': 61, 'learning_rate': 0.18647110155442756, 'max_depth': 4}. Best is trial 0 with value: 2.692562643754355.
# [I 2026-05-11 06:04:50,021] A new study created in memory with name: no-name-e14b122a-0985-4568-8d99-6344806fe0e1
# [I 2026-05-11 06:04:53,983] Trial 0 finished with value: 2.6678592310072338 and parameters: {'n_estimators': 200, 'learning_rate': 0.1664725826976676, 'max_depth': 2}. Best is trial 0 with value: 2.6678592310072338.
# [I 2026-05-11 06:04:56,985] Trial 1 finished with value: 2.6597807093597168 and parameters: {'n_estimators': 150, 'learning_rate': 0.15479826863291513, 'max_depth': 2}. Best is trial 1 with value: 2.6597807093597168.
# [I 2026-05-11 06:05:02,568] Trial 2 finished with value: 2.795953823601076 and parameters: {'n_estimators': 96, 'learning_rate': 0.19077309231612222, 'max_depth': 6}. Best is trial 1 with value: 2.6597807093597168.
# [I 2026-05-11 06:05:04,030] Trial 3 finished with value: 3.0590879331296916 and parameters: {'n_estimators': 74, 'learning_rate': 0.02781256460854788, 'max_depth': 2}. Best is trial 1 with value: 2.6597807093597168.
# [I 2026-05-11 06:05:15,446] Trial 4 finished with value: 2.885594083576684 and parameters: {'n_estimators': 169, 'learning_rate': 0.13244716749953722, 'max_depth': 7}. Best is trial 1 with value: 2.6597807093597168.
# [I 2026-05-11 06:05:19,097] A new study created in memory with name: no-name-00ab1211-8d66-47ba-a307-f3c66668f05a
# [I 2026-05-11 06:05:20,365] Trial 0 finished with value: 2.6577049252924905 and parameters: {'n_estimators': 64, 'learning_rate': 0.1653532267794611, 'max_depth': 2}. Best is trial 0 with value: 2.6577049252924905.
# [I 2026-05-11 06:05:25,495] Trial 1 finished with value: 2.746252198106794 and parameters: {'n_estimators': 81, 'learning_rate': 0.04303432834919756, 'max_depth': 7}. Best is trial 0 with value: 2.6577049252924905.
# [I 2026-05-11 06:05:27,262] Trial 2 finished with value: 2.6482717498802653 and parameters: {'n_estimators': 89, 'learning_rate': 0.1540948662207083, 'max_depth': 2}. Best is trial 2 with value: 2.6482717498802653.
# [I 2026-05-11 06:05:28,910] Trial 3 finished with value: 2.6436577470508498 and parameters: {'n_estimators': 83, 'learning_rate': 0.1591728048322532, 'max_depth': 2}. Best is trial 3 with value: 2.6436577470508498.
# [I 2026-05-11 06:05:33,440] Trial 4 finished with value: 2.755348336534229 and parameters: {'n_estimators': 93, 'learning_rate': 0.14337449071917482, 'max_depth': 5}. Best is trial 3 with value: 2.6436577470508498.
# [I 2026-05-11 06:05:35,472] A new study created in memory with name: no-name-b066da1b-8df8-49c5-9342-8bcd5edefa52
# [I 2026-05-11 06:05:39,204] Trial 0 finished with value: 2.73858042244258 and parameters: {'n_estimators': 77, 'learning_rate': 0.16264469592961847, 'max_depth': 5}. Best is trial 0 with value: 2.73858042244258.
# [I 2026-05-11 06:05:45,315] Trial 1 finished with value: 2.748410881107919 and parameters: {'n_estimators': 96, 'learning_rate': 0.03980979609461448, 'max_depth': 7}. Best is trial 0 with value: 2.73858042244258.
# [I 2026-05-11 06:05:49,330] Trial 2 finished with value: 2.692560137950985 and parameters: {'n_estimators': 103, 'learning_rate': 0.0858784051242736, 'max_depth': 4}. Best is trial 2 with value: 2.692560137950985.
# [I 2026-05-11 06:05:51,018] Trial 3 finished with value: 2.648718106329056 and parameters: {'n_estimators': 57, 'learning_rate': 0.15804741258468719, 'max_depth': 3}. Best is trial 3 with value: 2.648718106329056.
# [I 2026-05-11 06:06:03,534] Trial 4 finished with value: 2.924103523611264 and parameters: {'n_estimators': 184, 'learning_rate': 0.1984538711004298, 'max_depth': 7}. Best is trial 3 with value: 2.648718106329056.
# [I 2026-05-11 06:06:05,614] A new study created in memory with name: no-name-eeb19613-0f34-4292-9004-f792056c4f98
# [I 2026-05-11 06:06:14,178] Trial 0 finished with value: 2.890230254032295 and parameters: {'n_estimators': 112, 'learning_rate': 0.1722309064736673, 'max_depth': 8}. Best is trial 0 with value: 2.890230254032295.
# [I 2026-05-11 06:06:19,230] Trial 1 finished with value: 2.7954209915494066 and parameters: {'n_estimators': 76, 'learning_rate': 0.1368200691676634, 'max_depth': 7}. Best is trial 1 with value: 2.7954209915494066.
# [I 2026-05-11 06:06:22,070] Trial 2 finished with value: 3.7152045269482876 and parameters: {'n_estimators': 74, 'learning_rate': 0.012421654490968374, 'max_depth': 4}. Best is trial 1 with value: 2.7954209915494066.
# [I 2026-05-11 06:06:31,807] Trial 3 finished with value: 2.8208574078452626 and parameters: {'n_estimators': 177, 'learning_rate': 0.0125641996533518, 'max_depth': 6}. Best is trial 1 with value: 2.7954209915494066.
# [I 2026-05-11 06:06:34,611] Trial 4 finished with value: 2.6479279281008683 and parameters: {'n_estimators': 141, 'learning_rate': 0.18003063332130065, 'max_depth': 2}. Best is trial 4 with value: 2.6479279281008683.
# [I 2026-05-11 06:06:38,043] A new study created in memory with name: no-name-8452b129-1351-45fd-b431-952ea09f2478
# [I 2026-05-11 06:06:42,293] Trial 0 finished with value: 2.687267119819879 and parameters: {'n_estimators': 144, 'learning_rate': 0.13260440933654874, 'max_depth': 3}. Best is trial 0 with value: 2.687267119819879.
# [I 2026-05-11 06:06:54,390] Trial 1 finished with value: 2.8763403415874342 and parameters: {'n_estimators': 179, 'learning_rate': 0.15192721996923186, 'max_depth': 7}. Best is trial 0 with value: 2.687267119819879.
# [I 2026-05-11 06:06:56,384] Trial 2 finished with value: 2.702585582456518 and parameters: {'n_estimators': 51, 'learning_rate': 0.17739558311266537, 'max_depth': 4}. Best is trial 0 with value: 2.687267119819879.
# [I 2026-05-11 06:07:06,849] Trial 3 finished with value: 2.8578026597742645 and parameters: {'n_estimators': 180, 'learning_rate': 0.1863893213651103, 'max_depth': 6}. Best is trial 0 with value: 2.687267119819879.
# [I 2026-05-11 06:07:20,733] Trial 4 finished with value: 2.938837875749379 and parameters: {'n_estimators': 181, 'learning_rate': 0.1522681090205094, 'max_depth': 8}. Best is trial 0 with value: 2.687267119819879.
# [I 2026-05-11 06:07:25,946] A new study created in memory with name: no-name-1682b3ae-7451-46dc-ae17-59ba2b4b98f2
# [I 2026-05-11 06:07:30,652] Trial 0 finished with value: 2.852470975423866 and parameters: {'n_estimators': 63, 'learning_rate': 0.14585591767293157, 'max_depth': 8}. Best is trial 0 with value: 2.852470975423866.
# [I 2026-05-11 06:07:35,706] Trial 1 finished with value: 2.6645100145656313 and parameters: {'n_estimators': 171, 'learning_rate': 0.13506413863683467, 'max_depth': 3}. Best is trial 1 with value: 2.6645100145656313.
# [I 2026-05-11 06:07:41,467] Trial 2 finished with value: 2.6611071343715818 and parameters: {'n_estimators': 197, 'learning_rate': 0.025335624223937054, 'max_depth': 3}. Best is trial 2 with value: 2.6611071343715818.
# [I 2026-05-11 06:07:48,253] Trial 3 finished with value: 2.6741555656803424 and parameters: {'n_estimators': 174, 'learning_rate': 0.08232342420885475, 'max_depth': 4}. Best is trial 2 with value: 2.6611071343715818.
# [I 2026-05-11 06:07:53,583] Trial 4 finished with value: 2.6439522690747355 and parameters: {'n_estimators': 181, 'learning_rate': 0.07401222765261899, 'max_depth': 3}. Best is trial 4 with value: 2.6439522690747355.
#                      sheet  ...                                             params
# 0                    Лист1  ...          {'max_depth': 10, 'min_samples_leaf': 20}
# 1                    Лист1  ...          {'max_depth': 15, 'min_samples_leaf': 11}
# 2                    Лист1  ...          {'max_depth': 11, 'min_samples_leaf': 30}
# 3                    Лист1  ...           {'max_depth': 8, 'min_samples_leaf': 27}
# 4                    Лист1  ...          {'max_depth': 16, 'min_samples_leaf': 16}
# ...                    ...  ...                                                ...
# 3019  Лист3_смешанные_типы  ...  {'n_estimators': 83, 'learning_rate': 0.159172...
# 3020  Лист3_смешанные_типы  ...  {'n_estimators': 57, 'learning_rate': 0.158047...
# 3021  Лист3_смешанные_типы  ...  {'n_estimators': 141, 'learning_rate': 0.18003...
# 3022  Лист3_смешанные_типы  ...  {'n_estimators': 144, 'learning_rate': 0.13260...
# 3023  Лист3_смешанные_типы  ...  {'n_estimators': 181, 'learning_rate': 0.07401...
#
# [3024 rows x 7 columns]

# %% [markdown]
# А теперь используем рекурсивную стратегию предсказания модели:

# %%
def future_features(history, ts):
    hour = ts.hour
    month = ts.month
    dayofweek = ts.dayofweek
    return pd.DataFrame([{"hour": hour, "month": month, "dayofweek": dayofweek, "lag_24": history[-24], "lag_168": history[-168], "rolling_mean_24": np.mean(history[-24:]), "rolling_std_24": np.std(history[-24:]), "month_sin": np.sin(2 * np.pi * month / 12), "month_cos": np.cos(2 * np.pi * month / 12)}])

def recursive_forecast(model, history, start_time, steps):
    history = list(history)
    preds = []
    for i in range(1, steps + 1):
        ts = start_time + pd.Timedelta(hours=i)
        X_future = future_features(history, ts)
        pred = model.predict(X_future)[0]
        preds.append(pred)
        history.append(pred)
    return np.array(preds)

recursive_results = []

for name, sheet in df.items():
    if sheet.index.name == "ds" and "city" in sheet.columns:
        for city, city_df in sheet.groupby("city"):
            city_df = city_df.sort_index().copy()
            city_df["target_1"] = city_df["temperature_2m"].shift(-1)
            X_train, X_val, X_test, y_train, y_val, y_test = split_data(city_df, "target_1")
            test_index = X_test.index
            origins = test_index[:-168:168]
            for model_name in models:
                best_params = tune_model(model_name, X_train, X_val, y_train, y_val)
                model = get_model(model_name, best_params)
                model.fit(pd.concat([X_train, X_val]), pd.concat([y_train, y_val]))
                for origin in origins:
                    history = city_df.loc[:origin, "temp3erature_2m"].values
                    if len(history) < 168:
                        continue
                    y_pred = recursive_forecast(model, history, origin, 168)
                    y_true = city_df.loc[origin + pd.Timedelta(hours=1):origin + pd.Timedelta(hours=168), "temperature_2m"].values
                    if len(y_true) < 168:
                        continue
                    for h in horizons:
                        recursive_results.append({
                        "sheet": name,
                        "city": city,
                        "model": model_name,
                        "strategy": "recursive",
                        "origin": origin,
                        "horizon": h,
                        "MAE": mean_absolute_error(y_true[:h], y_pred[:h]),
                        "params": best_params
                    })
                    pd.DataFrame(recursive_results).to_csv("recursive_results_progress.csv", index=False)

recursive_results_df = pd.DataFrame(recursive_results)
recursive_results_df.to_csv("recursive_results_final.csv", index=False)
recursive_results_df
# Out:
# [I 2026-05-11 07:50:24,960] A new study created in memory with name: no-name-526b9537-1048-4048-ace7-de7eabae00d8
# [I 2026-05-11 07:50:25,020] Trial 0 finished with value: 2.7558976754741287 and parameters: {'max_depth': 6, 'min_samples_leaf': 10}. Best is trial 0 with value: 2.7558976754741287.
# [I 2026-05-11 07:50:25,141] Trial 1 finished with value: 2.7301490046372554 and parameters: {'max_depth': 15, 'min_samples_leaf': 1}. Best is trial 1 with value: 2.7301490046372554.
# [I 2026-05-11 07:50:25,179] Trial 2 finished with value: 3.2349117861395182 and parameters: {'max_depth': 4, 'min_samples_leaf': 4}. Best is trial 1 with value: 2.7301490046372554.
# [I 2026-05-11 07:50:25,291] Trial 3 finished with value: 2.5858381787350413 and parameters: {'max_depth': 20, 'min_samples_leaf': 6}. Best is trial 3 with value: 2.5858381787350413.
# [I 2026-05-11 07:50:25,386] Trial 4 finished with value: 2.384326014077143 and parameters: {'max_depth': 17, 'min_samples_leaf': 23}. Best is trial 4 with value: 2.384326014077143.
# [I 2026-05-11 07:50:28,870] A new study created in memory with name: no-name-bfcd66e0-fba8-41a1-b3aa-762de9fe735c
# [I 2026-05-11 07:50:29,699] Trial 0 finished with value: 2.316594192567494 and parameters: {'n_estimators': 127, 'max_depth': 8, 'min_samples_leaf': 29}. Best is trial 0 with value: 2.316594192567494.
# [I 2026-05-11 07:50:29,881] Trial 1 finished with value: 3.424803893299865 and parameters: {'n_estimators': 53, 'max_depth': 3, 'min_samples_leaf': 21}. Best is trial 0 with value: 2.316594192567494.
# [I 2026-05-11 07:50:30,756] Trial 2 finished with value: 2.1406829886625824 and parameters: {'n_estimators': 64, 'max_depth': 20, 'min_samples_leaf': 1}. Best is trial 2 with value: 2.1406829886625824.
# [I 2026-05-11 07:50:31,384] Trial 3 finished with value: 2.610151988831716 and parameters: {'n_estimators': 117, 'max_depth': 6, 'min_samples_leaf': 3}. Best is trial 2 with value: 2.1406829886625824.
# [I 2026-05-11 07:50:31,837] Trial 4 finished with value: 2.1596896159585723 and parameters: {'n_estimators': 55, 'max_depth': 10, 'min_samples_leaf': 13}. Best is trial 2 with value: 2.1406829886625824.
# [I 2026-05-11 07:52:45,161] A new study created in memory with name: no-name-4047587f-29d2-45af-b474-a03c2852b884
# [I 2026-05-11 07:52:58,456] Trial 0 finished with value: 2.0232406798270053 and parameters: {'n_estimators': 192, 'learning_rate': 0.07377593234930073, 'max_depth': 7}. Best is trial 0 with value: 2.0232406798270053.
# [I 2026-05-11 07:53:01,467] Trial 1 finished with value: 2.262772104165238 and parameters: {'n_estimators': 145, 'learning_rate': 0.14406712544899428, 'max_depth': 2}. Best is trial 0 with value: 2.0232406798270053.
# [I 2026-05-11 07:53:09,229] Trial 2 finished with value: 2.0344614802631242 and parameters: {'n_estimators': 190, 'learning_rate': 0.16342540006374454, 'max_depth': 4}. Best is trial 0 with value: 2.0232406798270053.
# [I 2026-05-11 07:53:19,650] Trial 3 finished with value: 2.048416228536221 and parameters: {'n_estimators': 173, 'learning_rate': 0.17015512680893968, 'max_depth': 6}. Best is trial 0 with value: 2.0232406798270053.
# [I 2026-05-11 07:53:26,766] Trial 4 finished with value: 2.0272727078977644 and parameters: {'n_estimators': 138, 'learning_rate': 0.15761677546250602, 'max_depth': 5}. Best is trial 0 with value: 2.0232406798270053.
# [I 2026-05-11 07:53:49,456] A new study created in memory with name: no-name-f126d02e-c122-4f9c-8dba-d80d6b93b752
# [I 2026-05-11 07:53:49,537] Trial 0 finished with value: 2.0546978039686428 and parameters: {'max_depth': 9, 'min_samples_leaf': 23}. Best is trial 0 with value: 2.0546978039686428.
# [I 2026-05-11 07:53:49,637] Trial 1 finished with value: 2.12769712538466 and parameters: {'max_depth': 12, 'min_samples_leaf': 10}. Best is trial 0 with value: 2.0546978039686428.
# [I 2026-05-11 07:53:49,741] Trial 2 finished with value: 2.128845477884114 and parameters: {'max_depth': 13, 'min_samples_leaf': 12}. Best is trial 0 with value: 2.0546978039686428.
# [I 2026-05-11 07:53:49,770] Trial 3 finished with value: 2.6548334415495756 and parameters: {'max_depth': 3, 'min_samples_leaf': 29}. Best is trial 0 with value: 2.0546978039686428.
# [I 2026-05-11 07:53:49,861] Trial 4 finished with value: 2.108303098782149 and parameters: {'max_depth': 10, 'min_samples_leaf': 1}. Best is trial 0 with value: 2.0546978039686428.
# [I 2026-05-11 07:53:57,020] A new study created in memory with name: no-name-0f2c6686-932c-4c58-b197-f0c39ee5948d
# [I 2026-05-11 07:53:57,722] Trial 0 finished with value: 1.857317975004256 and parameters: {'n_estimators': 81, 'max_depth': 17, 'min_samples_leaf': 25}. Best is trial 0 with value: 1.857317975004256.
# [I 2026-05-11 07:53:58,169] Trial 1 finished with value: 1.9041253371600602 and parameters: {'n_estimators': 59, 'max_depth': 9, 'min_samples_leaf': 2}. Best is trial 0 with value: 1.857317975004256.
# [I 2026-05-11 07:53:59,051] Trial 2 finished with value: 1.844897129163611 and parameters: {'n_estimators': 85, 'max_depth': 16, 'min_samples_leaf': 9}. Best is trial 2 with value: 1.844897129163611.
# [I 2026-05-11 07:53:59,602] Trial 3 finished with value: 1.8606217697175662 and parameters: {'n_estimators': 62, 'max_depth': 11, 'min_samples_leaf': 20}. Best is trial 2 with value: 1.844897129163611.
# [I 2026-05-11 07:54:00,172] Trial 4 finished with value: 1.9973389081132134 and parameters: {'n_estimators': 96, 'max_depth': 7, 'min_samples_leaf': 11}. Best is trial 2 with value: 1.844897129163611.
# [I 2026-05-11 07:56:16,772] A new study created in memory with name: no-name-4f7d1c33-03bc-4a61-97ae-d9bef6ed3e62
# [I 2026-05-11 07:56:18,705] Trial 0 finished with value: 1.9802179270393354 and parameters: {'n_estimators': 92, 'learning_rate': 0.13223795577725805, 'max_depth': 2}. Best is trial 0 with value: 1.9802179270393354.
# [I 2026-05-11 07:56:28,247] Trial 1 finished with value: 1.899992265853797 and parameters: {'n_estimators': 122, 'learning_rate': 0.11599685046050626, 'max_depth': 8}. Best is trial 1 with value: 1.899992265853797.
# [I 2026-05-11 07:56:30,940] Trial 2 finished with value: 1.9753226577711203 and parameters: {'n_estimators': 125, 'learning_rate': 0.1065182839141706, 'max_depth': 2}. Best is trial 1 with value: 1.899992265853797.
# [I 2026-05-11 07:56:34,008] Trial 3 finished with value: 1.8503210526028713 and parameters: {'n_estimators': 76, 'learning_rate': 0.13405978548036762, 'max_depth': 4}. Best is trial 3 with value: 1.8503210526028713.
# [I 2026-05-11 07:56:36,943] Trial 4 finished with value: 2.5381963922847053 and parameters: {'n_estimators': 59, 'learning_rate': 0.026975337591071562, 'max_depth': 5}. Best is trial 3 with value: 1.8503210526028713.
# [I 2026-05-11 07:56:50,132] A new study created in memory with name: no-name-e4724afe-de1f-4234-956e-b16c8382678e
# [I 2026-05-11 07:56:50,237] Trial 0 finished with value: 2.386909873668076 and parameters: {'max_depth': 18, 'min_samples_leaf': 18}. Best is trial 0 with value: 2.386909873668076.
# [I 2026-05-11 07:56:50,360] Trial 1 finished with value: 2.6687308031527035 and parameters: {'max_depth': 19, 'min_samples_leaf': 5}. Best is trial 0 with value: 2.386909873668076.
# [I 2026-05-11 07:56:50,417] Trial 2 finished with value: 2.522573663934878 and parameters: {'max_depth': 6, 'min_samples_leaf': 1}. Best is trial 0 with value: 2.386909873668076.
# [I 2026-05-11 07:56:50,545] Trial 3 finished with value: 2.782513864707536 and parameters: {'max_depth': 16, 'min_samples_leaf': 2}. Best is trial 0 with value: 2.386909873668076.
# [I 2026-05-11 07:56:50,642] Trial 4 finished with value: 2.3362903896967486 and parameters: {'max_depth': 17, 'min_samples_leaf': 30}. Best is trial 4 with value: 2.3362903896967486.
# [I 2026-05-11 07:57:02,305] A new study created in memory with name: no-name-57fd65c4-1a91-4c76-88a1-b83a9d8aef87
# [I 2026-05-11 07:57:03,210] Trial 0 finished with value: 2.199274246640595 and parameters: {'n_estimators': 76, 'max_depth': 16, 'min_samples_leaf': 1}. Best is trial 0 with value: 2.199274246640595.
# [I 2026-05-11 07:57:03,809] Trial 1 finished with value: 2.503791028488951 and parameters: {'n_estimators': 121, 'max_depth': 5, 'min_samples_leaf': 29}. Best is trial 0 with value: 2.199274246640595.
# [I 2026-05-11 07:57:04,334] Trial 2 finished with value: 2.0893489062269746 and parameters: {'n_estimators': 54, 'max_depth': 19, 'min_samples_leaf': 28}. Best is trial 2 with value: 2.0893489062269746.
# [I 2026-05-11 07:57:05,685] Trial 3 finished with value: 2.071047733486213 and parameters: {'n_estimators': 139, 'max_depth': 17, 'min_samples_leaf': 17}. Best is trial 3 with value: 2.071047733486213.
# [I 2026-05-11 07:57:06,876] Trial 4 finished with value: 2.114711645554018 and parameters: {'n_estimators': 141, 'max_depth': 10, 'min_samples_leaf': 29}. Best is trial 3 with value: 2.071047733486213.
# [I 2026-05-11 07:59:20,012] A new study created in memory with name: no-name-1eb6f5fb-0f3a-4b21-bb96-a6da9763df8a
# [I 2026-05-11 07:59:24,416] Trial 0 finished with value: 2.6287226358851696 and parameters: {'n_estimators': 150, 'learning_rate': 0.017391976677547376, 'max_depth': 3}. Best is trial 0 with value: 2.6287226358851696.
# [I 2026-05-11 07:59:28,527] Trial 1 finished with value: 2.116112655997673 and parameters: {'n_estimators': 56, 'learning_rate': 0.10247218601640067, 'max_depth': 8}. Best is trial 1 with value: 2.116112655997673.
# [I 2026-05-11 07:59:40,535] Trial 2 finished with value: 2.1927714579538304 and parameters: {'n_estimators': 156, 'learning_rate': 0.14131929854999056, 'max_depth': 8}. Best is trial 1 with value: 2.116112655997673.
# [I 2026-05-11 07:59:43,206] Trial 3 finished with value: 2.298775696861176 and parameters: {'n_estimators': 89, 'learning_rate': 0.05263959902364866, 'max_depth': 3}. Best is trial 1 with value: 2.116112655997673.
# [I 2026-05-11 07:59:55,911] Trial 4 finished with value: 2.1411899381698207 and parameters: {'n_estimators': 186, 'learning_rate': 0.14071079150973856, 'max_depth': 7}. Best is trial 1 with value: 2.116112655997673.
# [I 2026-05-11 08:00:13,250] A new study created in memory with name: no-name-8bfd3b9d-5e6c-44cc-b312-5b03bd8cdd3f
# [I 2026-05-11 08:00:13,279] Trial 0 finished with value: 3.0403839562542863 and parameters: {'max_depth': 3, 'min_samples_leaf': 26}. Best is trial 0 with value: 3.0403839562542863.
# [I 2026-05-11 08:00:13,378] Trial 1 finished with value: 2.0493642060024184 and parameters: {'max_depth': 20, 'min_samples_leaf': 21}. Best is trial 1 with value: 2.0493642060024184.
# [I 2026-05-11 08:00:13,408] Trial 2 finished with value: 3.0403839562542863 and parameters: {'max_depth': 3, 'min_samples_leaf': 25}. Best is trial 1 with value: 2.0493642060024184.
# [I 2026-05-11 08:00:13,514] Trial 3 finished with value: 2.0893852915403475 and parameters: {'max_depth': 17, 'min_samples_leaf': 12}. Best is trial 1 with value: 2.0493642060024184.
# [I 2026-05-11 08:00:13,616] Trial 4 finished with value: 2.073560331972867 and parameters: {'max_depth': 14, 'min_samples_leaf': 13}. Best is trial 1 with value: 2.0493642060024184.
# [I 2026-05-11 08:00:26,862] A new study created in memory with name: no-name-c2579002-8a54-4e13-85f8-c332e9a0d19a
# [I 2026-05-11 08:00:27,199] Trial 0 finished with value: 2.946968845892083 and parameters: {'n_estimators': 123, 'max_depth': 3, 'min_samples_leaf': 9}. Best is trial 0 with value: 2.946968845892083.
# [I 2026-05-11 08:00:27,455] Trial 1 finished with value: 2.4005999192737124 and parameters: {'n_estimators': 56, 'max_depth': 5, 'min_samples_leaf': 22}. Best is trial 1 with value: 2.4005999192737124.
# [I 2026-05-11 08:00:28,137] Trial 2 finished with value: 1.8310821446204546 and parameters: {'n_estimators': 78, 'max_depth': 16, 'min_samples_leaf': 14}. Best is trial 2 with value: 1.8310821446204546.
# [I 2026-05-11 08:00:28,815] Trial 3 finished with value: 1.8670443766283868 and parameters: {'n_estimators': 88, 'max_depth': 12, 'min_samples_leaf': 26}. Best is trial 2 with value: 1.8310821446204546.
# [I 2026-05-11 08:00:29,029] Trial 4 finished with value: 2.6437359267833602 and parameters: {'n_estimators': 53, 'max_depth': 4, 'min_samples_leaf': 20}. Best is trial 2 with value: 1.8310821446204546.
# [I 2026-05-11 08:02:49,127] A new study created in memory with name: no-name-9bf97ac0-e5bf-4c31-a952-8032a1cafc88
# [I 2026-05-11 08:02:57,208] Trial 0 finished with value: 1.7616326422846784 and parameters: {'n_estimators': 113, 'learning_rate': 0.058865197641357746, 'max_depth': 8}. Best is trial 0 with value: 1.7616326422846784.
# [I 2026-05-11 08:03:01,774] Trial 1 finished with value: 2.1688821275052668 and parameters: {'n_estimators': 120, 'learning_rate': 0.025502010179825813, 'max_depth': 4}. Best is trial 0 with value: 1.7616326422846784.
# [I 2026-05-11 08:03:09,534] Trial 2 finished with value: 1.7565434058118323 and parameters: {'n_estimators': 198, 'learning_rate': 0.1387263815946787, 'max_depth': 4}. Best is trial 2 with value: 1.7565434058118323.
# [I 2026-05-11 08:03:16,707] Trial 3 finished with value: 1.7769686883748836 and parameters: {'n_estimators': 182, 'learning_rate': 0.13892853463869287, 'max_depth': 4}. Best is trial 2 with value: 1.7565434058118323.
# [I 2026-05-11 08:03:21,636] Trial 4 finished with value: 1.8355397835520018 and parameters: {'n_estimators': 102, 'learning_rate': 0.08730931587794966, 'max_depth': 5}. Best is trial 2 with value: 1.7565434058118323.
# [I 2026-05-11 08:03:46,942] A new study created in memory with name: no-name-b2e23978-1f06-49d1-8c77-849a738efdf8
# [I 2026-05-11 08:03:46,998] Trial 0 finished with value: 2.1231325307592237 and parameters: {'max_depth': 6, 'min_samples_leaf': 6}. Best is trial 0 with value: 2.1231325307592237.
# [I 2026-05-11 08:03:47,082] Trial 1 finished with value: 1.874491469106876 and parameters: {'max_depth': 10, 'min_samples_leaf': 28}. Best is trial 1 with value: 1.874491469106876.
# [I 2026-05-11 08:03:47,120] Trial 2 finished with value: 2.3184037797094317 and parameters: {'max_depth': 4, 'min_samples_leaf': 22}. Best is trial 1 with value: 1.874491469106876.
# [I 2026-05-11 08:03:47,227] Trial 3 finished with value: 2.073298692247758 and parameters: {'max_depth': 14, 'min_samples_leaf': 7}. Best is trial 1 with value: 1.874491469106876.
# [I 2026-05-11 08:03:47,298] Trial 4 finished with value: 1.976082787314735 and parameters: {'max_depth': 8, 'min_samples_leaf': 21}. Best is trial 1 with value: 1.874491469106876.
# [I 2026-05-11 08:04:03,858] A new study created in memory with name: no-name-16370b9f-1c91-46f4-aad3-46154e58d2e0
# [I 2026-05-11 08:04:04,551] Trial 0 finished with value: 1.7208364632884383 and parameters: {'n_estimators': 65, 'max_depth': 15, 'min_samples_leaf': 3}. Best is trial 0 with value: 1.7208364632884383.
# [I 2026-05-11 08:04:05,374] Trial 1 finished with value: 1.715815630426047 and parameters: {'n_estimators': 97, 'max_depth': 13, 'min_samples_leaf': 16}. Best is trial 1 with value: 1.715815630426047.
# [I 2026-05-11 08:04:05,893] Trial 2 finished with value: 2.125213984567246 and parameters: {'n_estimators': 123, 'max_depth': 5, 'min_samples_leaf': 21}. Best is trial 1 with value: 1.715815630426047.
# [I 2026-05-11 08:04:06,601] Trial 3 finished with value: 1.7144640640130395 and parameters: {'n_estimators': 69, 'max_depth': 19, 'min_samples_leaf': 5}. Best is trial 3 with value: 1.7144640640130395.
# [I 2026-05-11 08:04:07,711] Trial 4 finished with value: 1.747898201723822 and parameters: {'n_estimators': 145, 'max_depth': 11, 'min_samples_leaf': 30}. Best is trial 3 with value: 1.7144640640130395.
# [I 2026-05-11 08:06:51,613] A new study created in memory with name: no-name-a3544b97-f321-40b2-808e-629b228ea5bc
# [I 2026-05-11 08:07:03,501] Trial 0 finished with value: 1.6921695813673399 and parameters: {'n_estimators': 183, 'learning_rate': 0.045843749718200946, 'max_depth': 7}. Best is trial 0 with value: 1.6921695813673399.
# [I 2026-05-11 08:07:10,641] Trial 1 finished with value: 1.7232412382327742 and parameters: {'n_estimators': 95, 'learning_rate': 0.12362845579716109, 'max_depth': 8}. Best is trial 0 with value: 1.6921695813673399.
# [I 2026-05-11 08:07:14,973] Trial 2 finished with value: 1.7465325069156883 and parameters: {'n_estimators': 110, 'learning_rate': 0.09730498097226065, 'max_depth': 4}. Best is trial 0 with value: 1.6921695813673399.
# [I 2026-05-11 08:07:28,956] Trial 3 finished with value: 1.7665540237990645 and parameters: {'n_estimators': 180, 'learning_rate': 0.18073263913627588, 'max_depth': 8}. Best is trial 0 with value: 1.6921695813673399.
# [I 2026-05-11 08:07:34,234] Trial 4 finished with value: 1.8076905862828778 and parameters: {'n_estimators': 175, 'learning_rate': 0.06624805032718678, 'max_depth': 3}. Best is trial 0 with value: 1.6921695813673399.
# [I 2026-05-11 08:08:08,373] A new study created in memory with name: no-name-1385fd24-5bae-4594-a0c5-77dfe60407cf
# [I 2026-05-11 08:08:08,457] Trial 0 finished with value: 1.65492211021251 and parameters: {'max_depth': 10, 'min_samples_leaf': 17}. Best is trial 0 with value: 1.65492211021251.
# [I 2026-05-11 08:08:08,561] Trial 1 finished with value: 1.6892166751409896 and parameters: {'max_depth': 13, 'min_samples_leaf': 15}. Best is trial 0 with value: 1.65492211021251.
# [I 2026-05-11 08:08:08,673] Trial 2 finished with value: 1.7938000798927787 and parameters: {'max_depth': 17, 'min_samples_leaf': 8}. Best is trial 0 with value: 1.65492211021251.
# [I 2026-05-11 08:08:08,771] Trial 3 finished with value: 1.6892526909510177 and parameters: {'max_depth': 13, 'min_samples_leaf': 14}. Best is trial 0 with value: 1.65492211021251.
# [I 2026-05-11 08:08:08,817] Trial 4 finished with value: 1.9389399722446394 and parameters: {'max_depth': 5, 'min_samples_leaf': 20}. Best is trial 0 with value: 1.65492211021251.
# [I 2026-05-11 08:08:28,805] A new study created in memory with name: no-name-79def02c-e5de-47ed-9bde-c11d056562cb
# [I 2026-05-11 08:08:29,601] Trial 0 finished with value: 1.4664548232173367 and parameters: {'n_estimators': 95, 'max_depth': 17, 'min_samples_leaf': 20}. Best is trial 0 with value: 1.4664548232173367.
# [I 2026-05-11 08:08:30,170] Trial 1 finished with value: 1.4767786643366876 and parameters: {'n_estimators': 53, 'max_depth': 17, 'min_samples_leaf': 4}. Best is trial 0 with value: 1.4664548232173367.
# [I 2026-05-11 08:08:31,176] Trial 2 finished with value: 1.46379597962214 and parameters: {'n_estimators': 118, 'max_depth': 15, 'min_samples_leaf': 14}. Best is trial 2 with value: 1.46379597962214.
# [I 2026-05-11 08:08:32,059] Trial 3 finished with value: 1.4737359928128655 and parameters: {'n_estimators': 109, 'max_depth': 17, 'min_samples_leaf': 29}. Best is trial 2 with value: 1.46379597962214.
# [I 2026-05-11 08:08:32,810] Trial 4 finished with value: 1.4640554577009395 and parameters: {'n_estimators': 88, 'max_depth': 16, 'min_samples_leaf': 18}. Best is trial 2 with value: 1.46379597962214.
# [I 2026-05-11 08:11:13,457] A new study created in memory with name: no-name-e3c998fb-a1f5-454d-a7e2-25196a58ef14
# [I 2026-05-11 08:11:22,573] Trial 0 finished with value: 1.4517492477707796 and parameters: {'n_estimators': 166, 'learning_rate': 0.04884933191900399, 'max_depth': 6}. Best is trial 0 with value: 1.4517492477707796.
# [I 2026-05-11 08:11:29,592] Trial 1 finished with value: 1.491751853917813 and parameters: {'n_estimators': 186, 'learning_rate': 0.035016922720169236, 'max_depth': 4}. Best is trial 0 with value: 1.4517492477707796.
# [I 2026-05-11 08:11:37,027] Trial 2 finished with value: 1.5025807451765838 and parameters: {'n_estimators': 113, 'learning_rate': 0.16613913299381963, 'max_depth': 7}. Best is trial 0 with value: 1.4517492477707796.
# [I 2026-05-11 08:11:41,773] Trial 3 finished with value: 1.468968788562681 and parameters: {'n_estimators': 73, 'learning_rate': 0.12323811841742481, 'max_depth': 7}. Best is trial 0 with value: 1.4517492477707796.
# [I 2026-05-11 08:11:45,346] Trial 4 finished with value: 2.8150055670398517 and parameters: {'n_estimators': 94, 'learning_rate': 0.011710823527158696, 'max_depth': 4}. Best is trial 0 with value: 1.4517492477707796.
#                        sheet  ...                                             params
# 0                      Лист1  ...          {'max_depth': 17, 'min_samples_leaf': 23}
# 1                      Лист1  ...          {'max_depth': 17, 'min_samples_leaf': 23}
# 2                      Лист1  ...          {'max_depth': 17, 'min_samples_leaf': 23}
# 3                      Лист1  ...          {'max_depth': 17, 'min_samples_leaf': 23}
# 4                      Лист1  ...          {'max_depth': 17, 'min_samples_leaf': 23}
# ...                      ...  ...                                                ...
# 163291  Лист3_смешанные_типы  ...  {'n_estimators': 166, 'learning_rate': 0.04884...
# 163292  Лист3_смешанные_типы  ...  {'n_estimators': 166, 'learning_rate': 0.04884...
# 163293  Лист3_смешанные_типы  ...  {'n_estimators': 166, 'learning_rate': 0.04884...
# 163294  Лист3_смешанные_типы  ...  {'n_estimators': 166, 'learning_rate': 0.04884...
# 163295  Лист3_смешанные_типы  ...  {'n_estimators': 166, 'learning_rate': 0.04884...
#
# [163296 rows x 8 columns]

# %% [markdown]
# Для recursive strategy прогноз строился из нескольких стартовых точек (origin), поэтому перед сравнением усредним значения MAE по всем origin для каждого города, модели и горизонта прогноза. После этого объединим результаты двух стратегий в одну таблицу.

# %%
recursive_summary = recursive_results_df.groupby(
    ["sheet", "city", "model", "strategy", "horizon"],
    as_index=False
).agg({
    "MAE": "mean",
    "params": "first"
})

all_results = pd.concat(
    [results_df, recursive_summary],
    ignore_index=True
)

all_results
# Out:
#                      sheet  ...                                             params
# 0                    Лист1  ...          {'max_depth': 10, 'min_samples_leaf': 20}
# 1                    Лист1  ...          {'max_depth': 15, 'min_samples_leaf': 11}
# 2                    Лист1  ...          {'max_depth': 11, 'min_samples_leaf': 30}
# 3                    Лист1  ...           {'max_depth': 8, 'min_samples_leaf': 27}
# 4                    Лист1  ...          {'max_depth': 16, 'min_samples_leaf': 16}
# ...                    ...  ...                                                ...
# 6043  Лист3_смешанные_типы  ...  {'n_estimators': 118, 'max_depth': 15, 'min_sa...
# 6044  Лист3_смешанные_типы  ...  {'n_estimators': 118, 'max_depth': 15, 'min_sa...
# 6045  Лист3_смешанные_типы  ...  {'n_estimators': 118, 'max_depth': 15, 'min_sa...
# 6046  Лист3_смешанные_типы  ...  {'n_estimators': 118, 'max_depth': 15, 'min_sa...
# 6047  Лист3_смешанные_типы  ...  {'n_estimators': 118, 'max_depth': 15, 'min_sa...
#
# [6048 rows x 7 columns]

# %% [markdown]
# Сравним среднее качество моделей для direct и recursive strategy по MAE:

# %%
all_results.groupby(
    ["strategy", "model"]
)["MAE"].mean().sort_values()
# Out:
# strategy   model
# recursive  Gradient Boosting    2.795064
#            Random Forest        2.853356
#            Decision Tree        2.994073
# direct     Gradient Boosting    3.066371
#            Random Forest        3.156869
#            Decision Tree        3.327398
# Name: MAE, dtype: float64

# %% [markdown]
# Посмотрим, как модели работают для разных городов:

# %%
all_results.groupby(
    ["city", "strategy", "model"]
)["MAE"].mean().sort_values()
# Out:
# city             strategy   model
# Находка          recursive  Gradient Boosting    2.312882
#                             Random Forest        2.356225
# Сочи             recursive  Gradient Boosting    2.470219
#                             Random Forest        2.528095
# Находка          recursive  Decision Tree        2.583120
# Санкт-Петербург  recursive  Gradient Boosting    2.664316
# Сочи             direct     Gradient Boosting    2.665746
# Находка          direct     Gradient Boosting    2.674786
# Сочи             recursive  Decision Tree        2.703401
# Геленджик        recursive  Gradient Boosting    2.720751
# Находка          direct     Random Forest        2.728626
# Сочи             direct     Random Forest        2.733611
# Геленджик        recursive  Random Forest        2.771168
# Санкт-Петербург  recursive  Random Forest        2.773219
# Геленджик        recursive  Decision Tree        2.779548
# Санкт-Петербург  recursive  Decision Tree        2.841669
# Находка          direct     Decision Tree        2.897146
# Сочи             direct     Decision Tree        2.917242
# Москва           recursive  Gradient Boosting    3.064278
#                             Random Forest        3.082948
# Санкт-Петербург  direct     Gradient Boosting    3.100460
# Геленджик        direct     Gradient Boosting    3.161361
# Санкт-Петербург  direct     Random Forest        3.228936
# Москва           recursive  Decision Tree        3.232345
# Геленджик        direct     Random Forest        3.252580
# Благовещенск     direct     Gradient Boosting    3.304045
# Санкт-Петербург  direct     Decision Tree        3.378714
# Благовещенск     direct     Random Forest        3.400076
# Геленджик        direct     Decision Tree        3.402769
# Москва           direct     Gradient Boosting    3.491827
# Благовещенск     recursive  Gradient Boosting    3.537940
# Москва           direct     Random Forest        3.597385
# Благовещенск     recursive  Random Forest        3.608479
#                  direct     Decision Tree        3.631048
# Москва           direct     Decision Tree        3.737467
# Благовещенск     recursive  Decision Tree        3.824356
# Name: MAE, dtype: float64

# %% [markdown]
# Для анализа устойчивости моделей построим зависимость средней ошибки MAE от горизонта прогнозирования:

# %%
mae_by_horizon = all_results.groupby(
    ["strategy", "horizon"]
)["MAE"].mean().reset_index()

mae_by_horizon
# Out:
#       strategy  horizon       MAE
# 0       direct        1  1.799858
# 1       direct        2  1.861340
# 2       direct        3  1.928858
# 3       direct        4  1.995640
# 4       direct        5  2.054817
# ..         ...      ...       ...
# 331  recursive      164  3.386568
# 332  recursive      165  3.391251
# 333  recursive      166  3.396396
# 334  recursive      167  3.403270
# 335  recursive      168  3.409995
#
# [336 rows x 3 columns]

# %% [markdown]
# Построим график изменения средней ошибки MAE для direct и recursive strategy:

# %% [markdown]
# Метрики качества рассчитывались на тестовом отрезке временного ряда. Для direct и recursive strategy использовались одинаковые метрики, что позволяет корректно сравнить качество различных подходов прогнозирования.

# %%
import matplotlib.pyplot as plt

for strategy, data in mae_by_horizon.groupby("strategy"):
    plt.plot(
        data["horizon"],
        data["MAE"],
        label=strategy
    )

plt.xlabel("Горизонт прогноза, часов")
plt.ylabel("MAE")
plt.title("Сравнение direct и recursive strategy")
plt.legend()
plt.grid()

plt.show()

# %% [markdown]
# ## Вывод
#
# В ходе экспериментов было установлено, что качество прогнозирования зависит от горизонта прогноза.
# На малых горизонтах direct strategy показывает более низкие значения MAE и обеспечивает более точный краткосрочный прогноз. Однако с увеличением горизонта ошибка для обеих стратегий постепенно возрастает, что является ожидаемым поведением для задач прогнозирования временных рядов.
# На больших горизонтах recursive strategy показала более устойчивое поведение: рост ошибки происходил медленнее, а итоговые значения MAE оказались сопоставимыми или немного ниже по сравнению с direct strategy.
# Среди рассмотренных моделей наилучшие результаты продемонстрировал Gradient Boosting. Random Forest также показал хорошие результаты, тогда как одиночное дерево решений оказалось менее точным.
# Таким образом:
# - direct strategy лучше подходит для краткосрочного прогноза;
# - recursive strategy показывает более стабильное качество на дальних горизонтах;
# - Gradient Boosting оказался наиболее эффективной моделью для данной задачи.

# %% [markdown]
# # Оценка качества прогноза с использованием дополнительных метрик
#
# Для более полного анализа качества прогнозирования дополнительно рассчитаем следующие метрики:
# - MAE - средняя абсолютная ошибка
# - MAPE — средняя абсолютная процентная ошибка
# - WAPE — взвешенная абсолютная процентная ошибка
# - Directional Accuracy — доля правильно предсказанных направлений изменения ряда
# - Directional R² — коэффициент детерминации для изменений ряда

# %%
from sklearn.metrics import mean_absolute_error, r2_score
import numpy as np
import pandas as pd
import ast

def mae(y_true, y_pred):
    return mean_absolute_error(y_true, y_pred)

def wape(y_true, y_pred):
    return np.sum(np.abs(y_true - y_pred)) / np.sum(np.abs(y_true))

def mape(y_true, y_pred):
    mask = y_true != 0
    return np.mean(np.abs((y_true[mask] - y_pred[mask]) / y_true[mask])) * 100

def directional_accuracy(y_true, y_pred):
    true_diff = np.diff(y_true)
    pred_diff = np.diff(y_pred)
    return np.mean(np.sign(true_diff) == np.sign(pred_diff))

def directional_r2(y_true, y_pred):
    true_diff = np.diff(y_true)
    pred_diff = np.diff(y_pred)
    return r2_score(true_diff, pred_diff)

def parse_params(params):
    if isinstance(params, dict):
        return params
    if isinstance(params, str):
        return ast.literal_eval(params)
    return {}

# %% [markdown]
# Расчёт метрик для direct strategy:

# %%
direct_metrics = []

for _, row in results_df.iterrows():
    sheet = df[row["sheet"]]
    city_df = sheet[sheet["city"] == row["city"]].sort_index().copy()
    h = int(row["horizon"])
    target_col = f"target_{h}"
    city_df[target_col] = city_df["temperature_2m"].shift(-h)
    X_train, X_val, X_test, y_train, y_val, y_test = split_data(city_df, target_col)
    params = parse_params(row["params"])
    model = get_model(row["model"], params)
    model.fit(pd.concat([X_train, X_val]), pd.concat([y_train, y_val]))
    y_pred = model.predict(X_test)
    direct_metrics.append({
        "sheet": row["sheet"],
        "city": row["city"],
        "model": row["model"],
        "strategy": "direct",
        "horizon": h,
        "MAE": mean_absolute_error(y_test, y_pred),
        "WAPE": wape(y_test.values, y_pred),
        "MAPE": mape(y_test.values, y_pred),
        "Directional Accuracy": directional_accuracy(y_test.values, y_pred),
        "Directional R2": directional_r2(y_test.values, y_pred)
    })

direct_metrics_df = pd.DataFrame(direct_metrics)
direct_metrics_df
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[61], line 12
#       8     city_df[target_col] = city_df["temperature_2m"].shift(-h)
#       9     X_train, X_val, X_test, y_train, y_val, y_test = split_data(city_df, target_col)
#      10     params = parse_params(row["params"])
#      11     model = get_model(row["model"], params)
# ---> 12     model.fit(pd.concat([X_train, X_val]), pd.concat([y_train, y_val]))
#      13     y_pred = model.predict(X_test)
#      14     direct_metrics.append({
#      15         "sheet": row["sheet"],
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/sklearn/base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/sklearn/ensemble/_gb.py:795, in BaseGradientBoosting.fit(self, X, y, sample_weight, monitor)
#     792     self._resize_state()
#     794 # fit the boosting stages
# --> 795 n_stages = self._fit_stages(
#     796     X_train,
#     797     y_train,
#     798     raw_predictions,
#     799     sample_weight_train,
#     800     self._rng,
#     801     X_val,
#     802     y_val,
#     803     sample_weight_val,
#     804     begin_at_stage,
#     805     monitor,
#     806 )
#     808 # change shape of arrays after fit (early-stopping or additional ests)
#     809 if n_stages != self.estimators_.shape[0]:
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/sklearn/ensemble/_gb.py:891, in BaseGradientBoosting._fit_stages(self, X, y, raw_predictions, sample_weight, random_state, X_val, y_val, sample_weight_val, begin_at_stage, monitor)
#     884         initial_loss = factor * self._loss(
#     885             y_true=y_oob_masked,
#     886             raw_prediction=raw_predictions[~sample_mask],
#     887             sample_weight=sample_weight_oob_masked,
#     888         )
#     890 # fit next stage of trees
# --> 891 raw_predictions = self._fit_stage(
#     892     i,
#     893     X,
#     894     y,
#     895     raw_predictions,
#     896     sample_weight,
#     897     sample_mask,
#     898     random_state,
#     899     X_csc=X_csc,
#     900     X_csr=X_csr,
#     901 )
#     903 # track loss
#     904 if do_oob:
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/sklearn/ensemble/_gb.py:497, in BaseGradientBoosting._fit_stage(self, i, X, y, raw_predictions, sample_weight, sample_mask, random_state, X_csc, X_csr)
#     494     sample_weight = sample_weight * sample_mask.astype(np.float64)
#     496 X = X_csc if X_csc is not None else X
# --> 497 tree.fit(
#     498     X, neg_g_view[:, k], sample_weight=sample_weight, check_input=False
#     499 )
#     501 # update tree leaves
#     502 X_for_tree_update = X_csr if X_csr is not None else X
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/sklearn/base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/sklearn/tree/_classes.py:1407, in DecisionTreeRegressor.fit(self, X, y, sample_weight, check_input)
#    1377 @_fit_context(prefer_skip_nested_validation=True)
#    1378 def fit(self, X, y, sample_weight=None, check_input=True):
#    1379     """Build a decision tree regressor from the training set (X, y).
#    1380
#    1381     Parameters
#    (...)   1404         Fitted estimator.
#    1405     """
# -> 1407     super()._fit(
#    1408         X,
#    1409         y,
#    1410         sample_weight=sample_weight,
#    1411         check_input=check_input,
#    1412     )
#    1413     return self
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/sklearn/tree/_classes.py:475, in BaseDecisionTree._fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     464 else:
#     465     builder = BestFirstTreeBuilder(
#     466         splitter,
#     467         min_samples_split,
#    (...)    472         self.min_impurity_decrease,
#     473     )
# --> 475 builder.build(self.tree_, X, y, sample_weight, missing_values_in_feature_mask)
#     477 if self.n_outputs_ == 1 and is_classifier(self):
#     478     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:

# %%
direct_metrics_partial_df = pd.DataFrame(direct_metrics)
direct_metrics_partial_df.to_csv("direct_metrics_partial.csv", index=False)
direct_metrics_partial_df
# Out:
#                      sheet  ... Directional R2
# 0                    Лист1  ...      -0.202573
# 1                    Лист1  ...      -0.277237
# 2                    Лист1  ...      -0.180034
# 3                    Лист1  ...      -0.129121
# 4                    Лист1  ...      -0.279054
# ...                    ...  ...            ...
# 2418  Лист3_смешанные_типы  ...       0.029638
# 2419  Лист3_смешанные_типы  ...       0.040106
# 2420  Лист3_смешанные_типы  ...       0.007065
# 2421  Лист3_смешанные_типы  ...       0.021702
# 2422  Лист3_смешанные_типы  ...       0.007204
#
# [2423 rows x 10 columns]

# %%
done = set(
    zip(
        direct_metrics_partial_df["sheet"],
        direct_metrics_partial_df["city"],
        direct_metrics_partial_df["model"],
        direct_metrics_partial_df["horizon"]
    )
)

direct_metrics = direct_metrics_partial_df.to_dict("records")

for _, row in results_df.iterrows():

    key = (
        row["sheet"],
        row["city"],
        row["model"],
        row["horizon"]
    )

    if key in done:
        continue

    sheet = df[row["sheet"]]

    city_df = sheet[
        sheet["city"] == row["city"]
    ].sort_index().copy()

    h = int(row["horizon"])

    target_col = f"target_{h}"

    city_df[target_col] = city_df["temperature_2m"].shift(-h)

    X_train, X_val, X_test, y_train, y_val, y_test = split_data(
        city_df,
        target_col
    )

    params = parse_params(row["params"])

    model = get_model(row["model"], params)

    model.fit(
        pd.concat([X_train, X_val]),
        pd.concat([y_train, y_val])
    )

    y_pred = model.predict(X_test)

    direct_metrics.append({
        "sheet": row["sheet"],
        "city": row["city"],
        "model": row["model"],
        "strategy": "direct",
        "horizon": h,
        "MAE": mean_absolute_error(y_test, y_pred),
        "WAPE": wape(y_test.values, y_pred),
        "MAPE": mape(y_test.values, y_pred),
        "Directional Accuracy": directional_accuracy(y_test.values, y_pred),
        "Directional R2": directional_r2(y_test.values, y_pred)
    })

    if len(direct_metrics) % 50 == 0:
        print(len(direct_metrics))

direct_metrics_df = pd.DataFrame(direct_metrics)

direct_metrics_df.to_csv(
    "direct_metrics_final.csv",
    index=False
)

direct_metrics_df
# Out:
# 2450
# 2500
# 2550
# 2600
# 2650
# 2700
# 2750
# 2800
# 2850
# 2900
# 2950
# 3000
#                      sheet          city  ... Directional Accuracy Directional R2
# 0                    Лист1  Благовещенск  ...             0.323674      -0.202573
# 1                    Лист1  Благовещенск  ...             0.379998      -0.277237
# 2                    Лист1  Благовещенск  ...             0.330210      -0.180034
# 3                    Лист1  Благовещенск  ...             0.263427      -0.129121
# 4                    Лист1  Благовещенск  ...             0.380325      -0.279054
# ...                    ...           ...  ...                  ...            ...
# 3019  Лист3_смешанные_типы          Сочи  ...             0.575751       0.126416
# 3020  Лист3_смешанные_типы          Сочи  ...             0.613435       0.126664
# 3021  Лист3_смешанные_типы          Сочи  ...             0.631021       0.121286
# 3022  Лист3_смешанные_типы          Сочи  ...             0.640813       0.125723
# 3023  Лист3_смешанные_типы          Сочи  ...             0.634914       0.140644
#
# [3024 rows x 10 columns]

# %% [markdown]
# Сравнение direct strategy по метрикам:

# %%
direct_metrics_df.groupby(["strategy", "model"])[
    ["MAE", "WAPE", "MAPE", "Directional Accuracy", "Directional R2"]
].mean()
# Out:
#                                  MAE  ...  Directional R2
# strategy model                        ...
# direct   Decision Tree      3.327398  ...       -0.264417
#          Gradient Boosting  3.066371  ...        0.047740
#          Random Forest      3.156869  ...       -0.017683
#
# [3 rows x 5 columns]

# %% [markdown]
# Расчёт метрик для recursive strategy:

# %%
def directional_r2(y_true, y_pred):
    true_diff = np.diff(y_true)
    pred_diff = np.diff(y_pred)
    if len(true_diff) < 5:
        return np.nan
    if np.var(true_diff) < 1e-8:
        return np.nan
    return r2_score(true_diff, pred_diff)

def wape(y_true, y_pred):
    denom = np.sum(np.abs(y_true))
    if denom < 1e-8:
        return np.nan
    return np.sum(np.abs(y_true - y_pred)) / denom

recursive_metrics = []

for name, sheet in df.items():
    if sheet.index.name == "ds" and "city" in sheet.columns:
        for city, city_df in sheet.groupby("city"):
            city_df = city_df.sort_index().copy()
            city_df["target_1"] = city_df["temperature_2m"].shift(-1)
            X_train, X_val, X_test, y_train, y_val, y_test = split_data(city_df, "target_1")
            test_index = X_test.index
            origins = test_index[:-168:168]
            for model_name in models:
                params_row = recursive_results_df[
                    (recursive_results_df["city"] == city) &
                    (recursive_results_df["model"] == model_name)
                ].iloc[0]
                params = parse_params(params_row["params"])
                model = get_model(model_name, params)
                model.fit(pd.concat([X_train, X_val]), pd.concat([y_train, y_val]))
                for origin in origins:
                    history = city_df.loc[:origin, "temperature_2m"].values
                    if len(history) < 168:
                        continue
                    y_pred = recursive_forecast(model, history, origin, 168)
                    y_true = city_df.loc[
                        origin + pd.Timedelta(hours=1):
                        origin + pd.Timedelta(hours=168),
                        "temperature_2m"
                    ].values
                    if len(y_true) < 168:
                        continue
                    for h in horizons:
                        recursive_metrics.append({
                            "sheet": name,
                            "city": city,
                            "model": model_name,
                            "strategy": "recursive",
                            "horizon": h,
                            "MAE": mae(y_true[:h], y_pred[:h]),
                            "WAPE": wape(y_true[:h], y_pred[:h]),
                            "MAPE": mape(y_true[:h], y_pred[:h]),
                            "Directional Accuracy": directional_accuracy(y_true[:h], y_pred[:h]),
                            "Directional R2": directional_r2(y_true[:h], y_pred[:h])
                        })
                        print(len(recursive_metrics))

recursive_metrics_df = pd.DataFrame(recursive_metrics)
recursive_metrics_df

# %% [markdown]
# Directional R^2 может принимать отрицательные значения. Это означает, что модель предсказывает изменения временного ряда хуже, чем простая базовая модель, использующая среднее изменение. Для коротких горизонтов и почти неизменяющихся участков ряда эта метрика может быть нестабильной, поэтому дополнительно использовалась метрика Directional Accuracy.

# %%
recursive_metrics_df.to_csv("recursive_metrics_final.csv", index=False)

# %% [markdown]
# Сравнение recursive strategy по метрикам:

# %%
recursive_metrics_df.groupby(["strategy", "model"])[
    ["MAE", "WAPE", "MAPE", "Directional Accuracy", "Directional R2"]
].mean()
# Out:
#                                   MAE  ...  Directional R2
# strategy  model                        ...
# recursive Decision Tree      2.994073  ...   -1.988395e+28
#           Gradient Boosting  2.795064  ...   -1.112809e+27
#           Random Forest      2.853356  ...   -7.995746e+26
#
# [3 rows x 5 columns]

# %% [markdown]
# Почистим некорректные значения Directional R^2, которые могли появиться при делении на очень маленькие значения:

# %%
recursive_metrics_df["Directional R2"] = recursive_metrics_df["Directional R2"].replace([np.inf, -np.inf], np.nan)
recursive_metrics_df.loc[recursive_metrics_df["Directional R2"].abs() > 1e6, "Directional R2"] = np.nan

# %% [markdown]
# Почистим некорректные значения WAPE:

# %%
recursive_metrics_df["WAPE"] = recursive_metrics_df["WAPE"].replace([np.inf, -np.inf], np.nan)

# %%
all_metrics = pd.concat(
    [direct_metrics_df, recursive_metrics_df],
    ignore_index=True
)

all_metrics
# Out:
#                        sheet  ... Directional R2
# 0                      Лист1  ...      -0.202573
# 1                      Лист1  ...      -0.277237
# 2                      Лист1  ...      -0.180034
# 3                      Лист1  ...      -0.129121
# 4                      Лист1  ...      -0.279054
# ...                      ...  ...            ...
# 166315  Лист3_смешанные_типы  ...       0.055087
# 166316  Лист3_смешанные_типы  ...       0.053887
# 166317  Лист3_смешанные_типы  ...       0.048664
# 166318  Лист3_смешанные_типы  ...       0.050437
# 166319  Лист3_смешанные_типы  ...       0.050482
#
# [166320 rows x 10 columns]

# %%
metrics_by_horizon = all_metrics.groupby(
    ["strategy", "horizon"]
)[
    ["MAE", "WAPE", "MAPE"]
].mean(numeric_only=True).reset_index()

metrics_by_horizon
# Out:
#       strategy  horizon       MAE      WAPE        MAPE
# 0       direct        1  1.799858  0.152565   57.081041
# 1       direct        2  1.861340  0.157901   58.850060
# 2       direct        3  1.928858  0.163635   61.414909
# 3       direct        4  1.995640  0.169465   63.590520
# 4       direct        5  2.054817  0.174479   64.976937
# ..         ...      ...       ...       ...         ...
# 331  recursive      164  3.386568  0.476887  104.462533
# 332  recursive      165  3.391251  0.477183  104.580379
# 333  recursive      166  3.396396  0.477845  104.706601
# 334  recursive      167  3.403270  0.478340  104.977330
# 335  recursive      168  3.409995  0.478887  105.082741
#
# [336 rows x 5 columns]

# %% [markdown]
# После объединения результатов direct и recursive strategy проанализируем изменение качества прогнозирования в зависимости от горизонта прогноза.

# %%
import matplotlib.pyplot as plt

for strategy, data in metrics_by_horizon.groupby("strategy"):
    plt.plot(
        data["horizon"],
        data["MAE"],
        label=strategy
    )

plt.xlabel("Горизонт прогноза, часов")
plt.ylabel("MAE")
plt.title("Изменение MAE по горизонту прогноза")
plt.legend()
plt.grid()

plt.show()

# %% [markdown]
# По графику видно, что ошибка MAE увеличивается с ростом горизонта прогнозирования. Это ожидаемо для многошагового прогноза: чем дальше прогноз, тем выше неопределённость. На коротких горизонтах direct strategy показывает более низкую ошибку, однако на дальних горизонтах recursive strategy демонстрирует более стабильное поведение.

# %% [markdown]
# Сделаем финальное усреднение метрик для каждой стратегии и модели:

# %%
all_metrics.groupby(
    ["strategy", "model"]
)[
    ["MAE", "WAPE", "MAPE", "Directional Accuracy", "Directional R2"]
].mean(numeric_only=True)
# Out:
#                                   MAE  ...  Directional R2
# strategy  model                        ...
# direct    Decision Tree      3.327398  ...       -0.264417
#           Gradient Boosting  3.066371  ...        0.047740
#           Random Forest      3.156869  ...       -0.017683
# recursive Decision Tree      2.994073  ...       -2.116313
#           Gradient Boosting  2.795064  ...       -0.469581
#           Random Forest      2.853356  ...       -0.735122
#
# [6 rows x 5 columns]

# %%
all_metrics.to_csv("all_metrics_final.csv", index=False)

# %% [markdown]
# # Вывод
#
# В ходе экспериментов было проведено сравнение direct и recursive strategy для задачи многошагового прогнозирования температуры.
#
# По метрикам MAE и MAPE recursive strategy показала более высокое качество прогнозирования. Наилучший результат продемонстрировала модель Gradient Boosting:
#
# - recursive + Gradient Boosting — MAE = 2.80;
# - direct + Gradient Boosting — MAE = 3.07.
#
# Это показывает, что recursive strategy обеспечивает более точный прогноз по абсолютной ошибке.
#
# Однако по метрикам Directional Accuracy и Directional R^2 direct strategy показала более стабильное качество прогнозирования направления изменения временного ряда. Особенно хорошо себя показал Gradient Boosting, для которого Directional R^2 оказался положительным.
#
# Также было замечено, что ошибка прогнозирования увеличивается с ростом горизонта прогноза, что является ожидаемым поведением для задач временных рядов.
#
# Среди рассмотренных моделей:
#
# - наилучшие результаты показал Gradient Boosting;
# - Random Forest показал близкое качество;
# - одиночное дерево решений оказалось наименее точным.
#
# Таким образом:
#
# - recursive strategy лучше подходит для минимизации абсолютной ошибки прогноза;
# - direct strategy демонстрирует более устойчивое качество при прогнозировании направления изменения ряда;
# - Gradient Boosting оказался наиболее эффективной моделью для данной задачи.
#
# В ходе лабораторной работы были выполнены:
# - извлечение и восстановление данных из Excel-файла;
# - очистка временных рядов и обработка пропусков;
# - анализ стационарности, сезонности и спектральных характеристик;
# - построение признаков для прогнозирования;
# - обучение моделей Decision Tree, Random Forest и Gradient Boosting;
# - сравнение direct и recursive strategy для многошагового прогнозирования температуры на неделю вперёд.
#
# Наилучшие результаты показал Gradient Boosting. По метрикам MAE и MAPE recursive strategy обеспечила более точный прогноз, тогда как direct strategy показала более устойчивое качество прогнозирования направления изменения временного ряда.
#
# Также было установлено, что ошибка прогнозирования увеличивается с ростом горизонта прогноза, что является ожидаемым поведением для задач временных рядов.
